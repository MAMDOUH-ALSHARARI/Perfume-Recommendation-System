# %%
import warnings

import numpy as np
import pandas as pd

# %%
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('golden_scent_perfumes2.csv')

# %%
df.head(2)
# Out:
#                             الاسم  السعر النهائي      الماركة        الجنس  \
# 0  كورلوف كوير ميثيك أو دو برفيوم           1116       كورلوف  رجالي/نسائي
# 1        كالفين كلاين ايفوريا ومن            298  كالفن كلاين        نسائي
#
#   نوع المنتج شخصية عطرك العائلة العطرية   الحجم سنة الإصدار  نسبة التركيز  \
# 0       عطور   كلاسيكية           جلدية  100 مل        2018  أو دو برفيوم
# 1       عطور      حيوية          فاكهية   50 مل        2005  أو دو برفيوم
#
#    ... قاعدة العطر Category                                       المكونات  \
# 0  ...      الجلود      NaN                                            NaN
# 1  ...  عنبر ، خشب     عطور  رمان ، لوتس بلوسوم ، بلاك أوركيد ، عنبر ، خشب
#
#   اللون النوتات العُليا النوتات المتوسطة النوتات القاعدية التركيبة  \
# 0   NaN             NaN              NaN              NaN      NaN
# 1   NaN             NaN              NaN              NaN      NaN
#
#   نوع المكياج مفتاح البحث
# 0         NaN         NaN
# 1         NaN         NaN
#
# [2 rows x 22 columns]

# %%
df.shape#.sort_values(ascending = False)
# Out:
# (8144, 22)

# %%
df['الجنس'].fillna('لا توجد معلومات', inplace=True)

# %%
df['شخصية عطرك'].fillna('لا توجد معلومات', inplace=True)

# %%
df['العائلة العطرية'].fillna('لا توجد معلومات', inplace=True)

# %%
df['نسبة التركيز'].fillna('لا توجد معلومات', inplace=True)

# %%
df = df[df['نوع المنتج'] == 'عطور']

# %%
#################################################################################

# %%
df.drop('نوع المنتج', axis = 1, inplace = True)

# %%
df.drop('سنة الإصدار', axis = 1, inplace = True)

# %%
df.drop('اللون', axis = 1, inplace = True)

# %%
df.drop('Category', axis = 1, inplace = True)

# %%
df.drop('النوتات العُليا', axis = 1, inplace = True)

# %%
df.drop('النوتات المتوسطة', axis = 1, inplace = True)

# %%
df.drop('النوتات القاعدية', axis = 1, inplace = True)

# %%
df.drop('التركيبة', axis = 1, inplace = True)

# %%
df.drop('نوع المكياج', axis = 1, inplace = True)

# %%
df.drop('مفتاح البحث', axis = 1, inplace = True)

# %%
#################################################################################

# %%
df = df.reset_index(drop=True)

# %%
df.head(2)
# Out:
#                             الاسم  السعر النهائي      الماركة        الجنس  \
# 0  كورلوف كوير ميثيك أو دو برفيوم           1116       كورلوف  رجالي/نسائي
# 1        كالفين كلاين ايفوريا ومن            298  كالفن كلاين        نسائي
#
#   شخصية عطرك العائلة العطرية   الحجم  نسبة التركيز  \
# 0   كلاسيكية           جلدية  100 مل  أو دو برفيوم
# 1      حيوية          فاكهية   50 مل  أو دو برفيوم
#
#                   مقدمة العطر                     قلب العطر قاعدة العطر  \
# 0  الماندرين، الصنوبر، العرعر  الزنجبيل، الجلابانوم، السوسن      الجلود
# 1                        رمان     لوتس بلوسوم ، بلاك أوركيد  عنبر ، خشب
#
#                                         المكونات
# 0                                            NaN
# 1  رمان ، لوتس بلوسوم ، بلاك أوركيد ، عنبر ، خشب

# %%
#################################################################################

# %%
gender = {}

# %%
counter = 1

# %%
for b in df.groupby(by = 'الجنس').size().index:
    if b == 'لا توجد معلومات':
            gender['لا توجد معلومات'] = 0
    else:
        gender[b] = counter
        counter = counter + 1

# %%
gender = dict(sorted(gender.items(), key=lambda x:x[1]))

# %%
for first_key, first_item in gender.items():
        df.loc[df['الجنس'] == first_key, 'الجنس'] = first_item

# %%
df = df.astype({ "الجنس" : "int64" })

# %%
#################################################################################

# %%
character = {}

# %%
counter = 1

# %%
for b in df.groupby(by = 'شخصية عطرك').size().index:
    if b == 'لا توجد معلومات':
            character['لا توجد معلومات'] = 0
    else:
        character[b] = counter
        counter = counter + 1

# %%
character = dict(sorted(character.items(), key=lambda x:x[1]))

# %%
for first_key, first_item in character.items():
        df.loc[df['شخصية عطرك'] == first_key, 'شخصية عطرك'] = first_item

# %%
df = df.astype({ "شخصية عطرك" : "int64" })

# %%
#################################################################################

# %%
family = {}

# %%
counter = 1

# %%
for b in df.groupby(by = 'العائلة العطرية').size().index:
    if b == 'لا توجد معلومات':
            family['لا توجد معلومات'] = 0
    else:
        family[b] = counter
        counter = counter + 1

# %%
family = dict(sorted(family.items(), key=lambda x:x[1]))

# %%
for first_key, first_item in family.items():
        df.loc[df['العائلة العطرية'] == first_key, 'العائلة العطرية'] = first_item

# %%
df = df.astype({ "العائلة العطرية" : "int64" })

# %%
#################################################################################

# %%
percentage = {}

# %%
counter = 1

# %%
for b in df.groupby(by = 'نسبة التركيز').size().index:
    if b == 'لا توجد معلومات':
            percentage['لا توجد معلومات'] = 0
    else:
        percentage[b] = counter
        counter = counter + 1

# %%
percentage = dict(sorted(percentage.items(), key=lambda x:x[1]))

# %%
for first_key, first_item in percentage.items():
        df.loc[df['نسبة التركيز'] == first_key, 'نسبة التركيز'] = first_item

# %%
df = df.astype({ "نسبة التركيز" : "int64" })

# %%
#################################################################################

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8143 entries, 0 to 8142
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   الاسم            8143 non-null   object
#  1   السعر النهائي    8143 non-null   int64
#  2   الماركة          8135 non-null   object
#  3   الجنس            8143 non-null   int64
#  4   شخصية عطرك       8143 non-null   int64
#  5   العائلة العطرية  8143 non-null   int64
#  6   الحجم            8125 non-null   object
#  7   نسبة التركيز     8143 non-null   int64
#  8   مقدمة العطر      6170 non-null   object
#  9   قلب العطر        6114 non-null   object
#  10  قاعدة العطر      6116 non-null   object
#  11  المكونات         4552 non-null   object
# dtypes: int64(5), object(7)
# memory usage: 763.5+ KB

# %%
#################################################################################

# %%
def toLi(x):
    col = 'مقدمة العطر'
    if not pd.isna(x[col]):
        x[col].replace('.', '')
        if '،' in x[col]:
            x = x[col].split('،')
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
        elif ',' in x[col]:
            x = x[col].split(',')
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
        else:
            x = x[col].split()
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
    else:
        return x[col]

# %%
df['مقدمة العطر'] = df.apply(toLi, axis=1)

# %%
#################################################################################

# %%
def toLi(x):
    col = 'قلب العطر'
    if not pd.isna(x[col]):
        x[col].replace('.', '')
        if '،' in x[col]:
            x = x[col].split('،')
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
        elif ',' in x[col]:
            x = x[col].split(',')
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
        else:
            x = x[col].split()
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
    else:
        return x[col]

# %%
df['قلب العطر'] = df.apply(toLi, axis=1)

# %%
#################################################################################

# %%
def toLi(x):
    col = 'قاعدة العطر'
    if not pd.isna(x[col]):
        x[col].replace('.', '')
        if '،' in x[col]:
            x = x[col].split('،')
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
        elif ',' in x[col]:
            x = x[col].split(',')
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
        else:
            x = x[col].split()
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
    else:
        return x[col]

# %%
df['قاعدة العطر'] = df.apply(toLi, axis=1)

# %%
#################################################################################

# %%
def toLi(x):
    col = 'المكونات'
    if not pd.isna(x[col]):
        x[col].replace('.', '')
        if '،' in x[col]:
            x = x[col].split('،')
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
        elif ',' in x[col]:
            x = x[col].split(',')
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
        else:
            x = x[col].split()
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
    else:
        return x[col]

# %%
df['المكونات'] = df.apply(toLi, axis=1)

# %%
#################################################################################

# %%
df['المكونات'].fillna(False, inplace=True)

# %%
df['مقدمة العطر'].fillna(False, inplace=True)

# %%
df['قلب العطر'].fillna(False, inplace=True)

# %%
df['قاعدة العطر'].fillna(False, inplace=True)

# %%
#################################################################################

# %%
df = df.reset_index(drop=True)

# %%
#################################################################################

# %%
for ind in df.index:
    row = df.loc[ind, ['المكونات', 'مقدمة العطر', 'قلب العطر', 'قاعدة العطر']]
    if not row['المكونات']:
        if row['قاعدة العطر'] and row['قلب العطر'] and row['مقدمة العطر']:
            result = row['قاعدة العطر'] + row['قلب العطر'] + row['مقدمة العطر']
            df.at[ind,'المكونات'] = result

# %%
#################################################################################

# %%
mask = df[df['المكونات'] == False].index

# %%
df.drop(mask , inplace=True)

# %%
df[df['المكونات'] == False]
# Out:
# Empty DataFrame
# Columns: [الاسم, السعر النهائي, الماركة, الجنس, شخصية عطرك, العائلة العطرية, الحجم, نسبة التركيز, مقدمة العطر, قلب العطر, قاعدة العطر, المكونات]
# Index: []

# %%
for ind in df.index:
    row = df.loc[ind, ['المكونات']]
    x = []
    for i in row:
        for a in i:
            if not a == '' and not a == ' ':
                if '.' in a:
                    x.append(a.replace('.', ''))
                else:
                    x.append(a)
    df.at[ind,'المكونات'] = x

# %%
for ind in df.index:
    row = df.loc[ind, ['المكونات']]
    for i in row:
        for a in i:
            print(a)
# Out:
# الجلود
# الزنجبيل
# الجلابانوم
# السوسن
# الماندرين
# الصنوبر
# العرعر
# رمان
# لوتس بلوسوم
# بلاك أوركيد
# عنبر
# خشب
# الجلود
# أخشاب الصندل
# القرفة
# زيت الورد
# الورد البلغاري
# الفلفل الأسود
# هيل
# كمون
# جوزة الطيب
# زهر البرتقال
# شمام
# باتشولي
# نجيل الهند
# أوراق الغار
# البتيتغرين
# البرغموت
# الليمون الأمالفي
# البرتقال
# الكزبرة
# اللافندر
# إيليمي
# العرعر
# المريمية
# زهر البرتقال
# القرنفل
# الفلفل
# الزعتر
# خشب الصندل
# الباتشولي
# المسك
# نجيل الهند
# طحلب السنديان
# خشب الورد البرازيلي
# خشب الأرز
# إكليل الجبل
# البرغموت
# اليوسفي
# الليمون
# زهر البرتقال
# الفلفل الوردي
# الفاوانيا
# قلب الباتشولي
# زيت خشب الأرز
# نجيل الهند
# اللابدانوم
# طحلب البلوط
# الأناناس الحلو
# الهيل
# القرفة
# الليمون
# الزنجبيل
# الجريب فروت
# الورد
# الباتشولي
# العود
# أخشاب الصندل
# نجيل الهند
# السرو
# الفلفل
# اليانسون النجمي
# الريحان
# توت العرعر
# الماندرين
# كلمنتين
# الفانيليا
# العنبر
# الباتشولي
# السوسن
# الألدهيدات
# الأرز
# البنزوين
# الياسمين
# الإيلنغ
# الماندرين الصقلي
# الخوخ الأبيض
# نجيل الهند
# الباتشولي
# الفلفل الوردي
# الهيل
# سيترون
# القرفة
# الزنجبيل
# الكشمش الأسود
# البرجموت
# الجريب فروت
# الأخشاب
# الإيلنغ
# الياسمين
# الجاردينيا
# الكشمش الأسود
# البرجموت
# الزنبق
# العنبر
# المسك
# الباتشولي
# يلانج يلانج
# الياسمين
# نفحات
# الفواكه
# أخشاب الصندل
# المسك
# العنبر
# العود
# الليمون
# التفاح الأخضر وروائح البحر
# العنبر
# نجيل الهند
# تونكا
# الجلود
# العسل
# نجيل الهند
# أخشاب الغاياك
# الباتشولي
# التبغ
# الزنجبيل
# البرجموت
# الليمون الأخضر
# البرغموت
# اليوسفي
# البنفسج
# الياسمين
# خشب الغاياك
# الباتشولي
# الحبهان
# أوراق البنفسج
# الليمون
# هيل
# القهوة
# الغرنوقي
# أمبروكسيد
# أخشاب الكشمير
# خشب الأرز الأبيض
# المسك الأبيض
# الخوخ
# الفلفل الوردي
# الهيل
# الزعفران
# جوزة الطيب
# إبرة الراعي
# المر
# العود
# البتشولي
# الجلد
# الستيراكس
# البخور
# الجلود
# العنبر
# الباتشولي
# المسك
# الفانيليا
# أخشاب الصندل
# الورد التركي المطلق
# إبرة الراعي
# العود
# الزعفران
# الفلفل الأسود
# أوراق القرنفل
# الباتشولي
# الأخشاب
# الفانيليا
# الفريزيا
# الياسمين
# ياسمين سمباك
# الفلفل الأسود
# البرجموت
# التفاح الأخضر
# المسك الأبيض
# نجيل الهند
# الفانيليا
# الباتشولي
# الورد
# الياسمين
# البرتقال
# البرجموت
# السوسن
# الياسمين
# الباتشولي
# البنزين
# نجيل الهند
# إبرة الراعي
# إكليل الجبل
# اللافندر
# الفلفل الوردي
# الماندرين البرتقالي
# الزنجبيل
# البرتقال الذهبي
# الباتشولي
# رذاذ بحري
# نوتات جورماند
# الأخشاب
# الياسمين
# أزهار جوز الهند
# الفريزيا
# زنبق الوادي
# كحول
# عطر
# أكوا (ماء)
# ألفا إيزوميثيل أيونون
# كحول بنزيل
# بنزيل بنزوات
# بنزيل ساليسيلات
# قرفة
# كحول سيناميل
# سيترال
# سيترونيلول
# يوجينول
# فارنيسول
# جيرانيول
# هيكسيل سينامال
# هيدروكسي سيترونيلال
# ليمونين
# لينالول
# دينات الكحول (كحول SD 39-C)
# عطر (عطر)
# أكوا (ماء)
# جيرانيول
# سيترونيلول
# ليمونين
# لينالول
# سيترال
# عود الصندل
# عود الأرز
# المسك الأبيض
# جوز الهند
# الورد
# البطيخ
# التفاح الأخضر
# التوت
# الفاونيا
# عصير الكمثرى
# البرتقال
# الجاردينيا
# زهور الصبار
# شجرة جوشوا
# أمبروكسان
# الورد
# البرتقال
# الأرز
# الهيل
# السمسم
# زهور البرتقال
# البلح
# البرغموت والليمون والبرتقال
# رمان
# عنب
# مشمش
# تين
# الفانيليا والمسك والعنبر
# الفواكه الإستوائية
# البرجموت
# الليمون
# الماندرين
# الشاي الأبيض
# الياسمين
# النيرولي
# زهور البرتقال
# أمبروكسان
# أخشاب الأرز
# المسك
# الطحلب
# زهر العسل
# الورد
# دافانا
# ملاحظات خضراء
# البرغموت
# زهر البرتقال
# السوسن
# نرجس
# الورد
# زنبق الوادي
# يلانج
# نجيل الهند
# خشب الصندل
# طحلب البلوط
# جلد
# العنبر
# أخشاب الصندل
# الهيل
# المسك
# الفانيليا
# العنبر
# زهور البرتقال
# الحمضيات
# ليمون فيربينا
# الجريب فروت
# الماندرين
# اللافندر
# الزنجبيل
# جوزة الطيب
# خشب الأرز
# المسك الأبيض
# البنزوين
# العنبر
# حبوب التونكا
# الفلفل
# المسك
# الميموزا
# زهور اليوسفي
# الزنبق المائي
# الأرجواني
# زهور البرتقال
# نجيل الهند
# السوسن
# العود
# أخشاب الصندل
# العنبر
# الورد
# إبرة الراعي
# زهور البرتقال
# اللافاندين
# الهيل
# الزعفران
# الفانيليا
# المسك
# الباتشولي
# العنبر
# الياسمين
# يلانغ يلانغ
# الورد
# الأوسمانثوس
# زهر البرتقال
# البرغموت
# الليمون
# البرتقال الحلو
# الجلود
# المسك
# الباتشولي
# أخشاب الأرز
# أمبروكس
# الياسمين
# الورد
# الفواكه الحمراء
# البرتقال
# الراوند
# الأفسنتين
# اليانسون
# الشمر
# الخزامى
# المسك
# الفانيليا السوداء
# برغموت
# ليمون
# برتقال ماندرين
# ياسمين سامباك
# زهر البرتقال
# فانيليا
# فانيليا
# مِسك أبيض
# التوابل
# الأخشاب
# الزهور البيضاء
# العنبر
# الفانيليا
# الكمثرى
# الفريزيا
# المسك
# التبغ
# الفانيليا
# الباتشولي
# الزعفران
# حبوب التونكا
# الهيل
# القرفة
# الألدهيدات
# روائح عشبية
# نبات الطرخون
# المريمية
# البارغموت
# الليمون
# خشب الصندل
# الباتشولي
# جذور السوسن
# الياسمين
# أخشاب الأرز
# التبغ
# الورد
# العنبر
# التونكا
# المسك
# الفانيليا
# طحلب البلوط
# الباتشولي
# نجيل الهند
# أخشاب الأرز
# أخشاب الصندل
# طحلب البلوط
# حبوب التونكا
# المسك
# إبرة الراعي
# القرفة
# الزعفران
# التبغ الأشقر
# السفرجل
# البرجموت
# الليمون
# الجريب فروت
# الماندرين
# الهيل
# الفلفل
# المسك
# أخشاب الصندل
# الورد
# الجريب
# فروت
# كحول
# عطر
# أكوا
# ماء
# لينالول
# ليمونين
# سيترونيلول
# ألفا إيزوميثيل أيونون
# هيدروكسي سيترونيلال
# هيكسيل سينامال
# يوجينول
# سيترال
# جيرانيول
# بنزيل بنزوات
# كحول سيناميل
# بنزيل ساليسيلات
# كومارين
# كحول بنزيل
# مسك
# فانيلا
# عنبر
# ياسمين
# بنفسج
# باتشولي
# خشب صندل
# البرغموت
# الفراولة
# التوت البري
# تفاح
# زعفران
# خوخ
# البرقوق
# زهر البرتقال
# الياسمين
# العود
# خشب الصندل
# الفانيليا
# ليمون أمالفي
# البرتقال
# الأرز الفرجيني
# البرجموت
# العود
# المسك الأبيض
# البخور
# العنبر
# الجاوي
# أوراق الباتشولي
# الورد التركي
# الزنجبيل الهندي
# الحمضيات
# الكمثرى
# الأفسنتين
# مجموعة البخور الطازجة
# أشجار الكاري
# خشب الأرز الصيني
# النرجس
# الورد التركي
# ميسور خشب الصندل
# الجلد المغربي
# المسك
# نجيل الهند
# المسك
# العنبر
# الحرير
# أوراق الباردي
# الباتشولي
# الياسمين
# الإيلنغ
# زهور البرتقال
# البرجموت
# توت العليق
# الإيلنغ
# الكشمش الأسود
# الكمثرى
# البرغموت
# الياسمين
# البنفسج
# زنبق الوادي
# المكونات الخشبية
# المسك
# خشب الصندل
# مانجو
# برتقال حلو
# ياسمين سامباك
# يلنغ يلانغ
# زهر البرتقال
# عود مغربي
# نجيل الهند
# خشب أرز
# طحلب البلوط
# الجلود
# العنبر
# السوسن
# الفلفل
# الوردي
# الورد
# الياسمين
# زهور الحائط الحار
# السوسن
# البودرة
# أوراق الكشمش الاسود
# التوت البري
# الكمثرى
# خشب الصندل
# بربون الفانيليا
# المسك الأبيض
# العنبر
# الفانيليا
# بلسم البيرو
# أخشاب الكشمير
# الكستناء
# الأخشاب
# العرعر
# القرنفل
# الفلفل الوردي
# زهرة البرتقال
# دينات الكحول
# كحول إس دي 39-ج
# أكوا
# ماء
# عطر
# ليمونين
# لينالول
# إيثيل هيكسيل ميثوكسيسينامات
# سيترال
# بوتيل ميثوكسيديبنزويل ميثان
# إيثيل هكسيل ساليسيلات
# سيترونيلول
# جيرانيول
# فارنيسول
# الخزامى
# البرغموت
# أوراق الأناناس
# إبرة الراعي
# التفاح
# الورد
# حبوب التونكا
# خشب الصندل
# الياسمين
# خشب العود
# العنبر
# الباتشولي
# الهيل
# القهوة
# الياسمين
# بلسم التنوب
# الفانيليا
# دهن العود اللاوسي
# الكشمش
# الأسود
# العنبر
# أخشاب الأرز
# أخشاب الصندل
# الفانيليا
# ياسمين سمباك
# حجر الدم
# البرجموت
# الثلج
# البودرة
# البرقوق الإيطالي
# الزعفران
# الورد البلغاري
# ياسمين
# زهر السوسن
# العنبر
# نجيل الهند
# البردي
# الخزامي
# زنابق الوادي
# إكليل الجبل
# الليمون
# أخشاب الأرز
# زهور إبره الراعي
# التونكا
# العود
# نجيل الهند
# الكزبرة
# الريحان
# الجريب فروت
# الزنجبيل
# زهر البرتقال
# الهيل
# التبغ
# العنبر الحسي
# خشب الأرز
# البرجموت
# الورد
# حبوب التونكا
# الفانيليا
# الباتشولي
# الأخشاب
# الأناناس
# الكشمش الأسود
# أخشاب الباتولا
# العنبر
# الفانيليا
# الماء
# الكحول
# البطيخ
# الفلفل الوردي
# الجريب فروت
# الهيل
# الريحان
# اللافندر
# نجيل الهند
# طحلب البلوط
# الباتشولي
# زهور
# الفلفل
# مسك
# باتشولي
# عنبر
# أخشاب العنبر
# اللبان
# المسك
# السوسن
# الفلفل الأبيض
# المصطكي
# الأناناس
# زهور السوسن
# الياسمين
# الفلفل الوردي
# المسك
# الباتشولي
# العنبر
# الفانيليا
# جوزة الطيب
# ورد الجوري
# برجموت
# مسك
# العنبر
# الأرز
# الباتشولي
# طحلب السنديان
# الجلود
# الجريب فروت
# زهر البرتقال
# التبغ
# الفلفل الأسود
# البرغموت
# الماندرين البرتقالي
# البنفسج
# الزنجبيل
# الريحان
# الباتشولي
# المسك الأبيض
# أمبروكسان
# الياسمين
# الفاونيا
# الداتورة
# توت العليق
# الكمثرى
# البرجموت
# البرغموت
# اليوسفي
# زهر البرتقال
# التفاح
# شيح
# شاي
# فلفل
# طحلب السنديان
# المسك
# تونكا
# الباتشولي
# اللافندر الفرنسي
# الهيل
# الليمون
# العنبر
# طحلب البلوط
# حبوب التونكا
# كلاري سيج
# إبرة الراعي
# لافندر
# الجريب فروت
# أوراق البنفسج
# فلفل سيتشوان
# برغموت
# ليمون
# زهرة يلانغ يلانغ
# خوخ
# روائح أوراق الشجر الخضراء,سوسن
# ياسمين
# ورد
# بتشول
# نجيل الهند,فانيليا
# أبوبوناكس
# حبوب التونكا
# لبان
# خشب الصندل
# مسك
# زباد
# عنبر
# جلد
# كومارين
# بلسم بيرو
# الكباد
# ورد ماي
# فاوانيا,فريسيا صفراء
# ورد ماي
# ياسمين
# زهرة يلانغ يلانغ,سوسن
# خشب الصندل
# حزازيات
# مسك
# حبوب التونكا
# برغموت كالابريا
# اليوسفي الإيطالي
# جوهر الليمون
# أوراق البنفسج المطلقة
# فلفل بوربون
# جزيئات كاسكالون
# الجالبانوم
# جوزة الطيب
# البنفسج المطلق
# أمبروكس
# خشب الأرز الأمريكي
# نجيل بوربون
# ليمبانول
# الباتشولي الإندونيسي
# سيتالوكس
# التبغ
# العود
# الجلود
# جذور
# السوسن
# التوت
# أخشاب
# الصندل
# الورد
# الياسمين
# العسل
# الشاي
# الأخضر
# الزعفران
# توت العرعر
# الجريب فروت
# الوردة السوداء
# الجلود
# البنفسج
# كشميران
# التوت
# القندس
# الزباد
# أمريس
# الأعشاب
# أرز تكساس
# الأرز الأطلسي
# أمبراروم
# الباتشولي
# أوراق الباتشولي
# أخشاب الغاياك
# زيت سيبرول
# ستيراكس
# العرعر
# الفلفل الأسود
# البقدونس
# الزعفران
# البابونج
# الكمون
# التوت البري
# الياسمين
# الزهور البيضاء
# الشاي الأسود
# أوسمانثوس الشرقي
# الجلود
# الفواكه
# الورد البلغاري
# أزهار السوسن
# الكاكاو
# الباتشولي
# شامبانيا
# رائحه الفواكه
# براعم الخوخ
# الأخشاب
# المسك الأبيض
# العنبر
# المسك
# الفانيليا
# الباتشولي
# أخشاب الصندل
# الياسمين
# النيرولي
# مسك الروم
# حبوب التونكا
# الكمثرى
# البرجموت
# اليوسفي
# الفلفل الوردي الطازج
# زهور تندر
# الباتشولي
# التوابل
# الأخشاب
# الزهور
# العنبر
# الجلود
# الفانيليا
# حبوب التونكا
# العسل
# الياسمين
# الورد
# زهور البرتقال
# الزعفران
# البرجموت
# نسيم البحر
# خشب الصندل
# المسك
# الطاقة الشمسية
# الأزهار
# البرجموت
# البرتقال
# التوت البري
# البرقوق الداكن
# البرغموت
# الزهرة الحمراء (سيلوزيا)
# ياسمين السامباك
# بلوماريا رينبو
# الكشمير
# الباتشولي
# البرالين السائل
# الكمثرى
# الكاموميل
# البرجموت
# زهر الفريزيا
# زهرة البتلة
# هيليوتروب
# الباتشولي
# المسك
# الفانيليا
# توت العليق
# الورد
# الفلفل الوردي
# الورد
# حلوى المعكرونة
# الياسمين
# الزعرور البري
# الفانيليا
# المسك الأبيض
# البرجموت
# البنفسج
# زهر البرتقال
# الورد
# السوسن
# خشب الصندل
# العنبر
# الفانيليا
# الكحول
# عطر
# ماء
# هيدروكسي سيترونيلال
# ليمونين
# لينالول
# ساليسيلات البنزيل
# هيكسيل سينامال
# بوتيل فينيل ميثيل بروبيونال
# كومارين
# ألفا-أيزو ميثيل أيونون
# بولي إيثيلين جليكول ٤۰ زيت خروع مهدرج
# سيترونيلول
# سيترال
# غيرانيول
# فارنيسول
# أكاي بيري
# زهر الماندرين والأناناس
# نجمة الياسمين والفانيليا الأوركيد
# خشب الصندل والمسك والفانيليا
# الإيلنغ
# زهور البرتقال
# البرجموت
# السوسن
# الياسمين
# الورد
# الهيل
# الجلود
# البخور
# القرفة
# أخشاب الغاياك
# أخشاب الأرز
# الباتشولي
# اللافندر
# الكشمش الأسود
# الجريب فروت
# البطيخ
# البرغموت
# البرتقال
# الأوكالبتوس
# الحبهان
# الفلفل الأسود
# القرفة
# خشب الصندل
# المكونات الخشبية
# البخور
# البرجموت
# النعناع
# أعشاب بحرية
# أخشاب البتولا
# التفاح
# البرقوق
# الكشمش الأسود
# الأناناس
# الفراولة
# الشمام
# التنوب
# الزيزفون
# اليوسفي
# الهيل
# الجريب فروت
# الريحان
# الفلفل الوردي
# الزنجبيل
# اللوتس
# الياسمين
# شيح
# زهر البرتقال
# زهر بخور مريم
# الورد
# الأوركيد
# المسك
# الأرز
# أخشاب الصندل
# الفانيليا
# التوفي
# الزعفران
# اللبن
# اللوز
# أوليبانوم
# الزعفران
# الفلفل الوردي
# الزنجبيل
# العنبر
# الجلود
# الطحلب
# العود
# الورد
# البنفسج
# أخشاب الغاياك
# سيبرول
# البرتقال المر
# اللبان
# خشب الرطب
# أخشاب الأرز
# نجيل الهند
# المسك
# الكمثرى
# الفلفل الوردي
# اللافندر
# الشيح
# مكونات خضراء
# البرغموت
# برتقال الماندرين
# الأوسمانثوس
# الياسمين
# إبرة الراعي
# المسك
# الورد
# البنفسج الأبيض
# رقيب الشمس
# الليلك
# المسك
# فانيلا
# العنبر
# العنبر
# الفانيليا
# الأخشاب
# البنزوين
# الأرز
# الباتشولي
# الطحالب
# الفلفل الوردي
# الكزبرة
# البنفسج
# البرغموت
# الليمون
# زهرة الزيتون
# الخشب
# فول التونكا
# الكراميل
# الجلود
# السكر البني
# المشروبات الكحولية
# الباتشولي
# أخشاب الأرز
# الخمر الأحمر
# توت العليق
# الفواكه المجففة
# التوت الأحمر
# نجيل الهند
# الجلود
# المسك
# السوسن
# الكراميل
# العنبر
# البرجموت
# الفلفل الوردي
# الكشمير
# العنبر
# أخشاب الأرز
# أخشاب الصندل
# اللابدانوم
# التبغ
# النيرولي
# الورد
# الشاي
# القرفة
# القرنفل
# توت العرعر
# الرفيق
# الفلفل الوردي
# الرمان واليوسفي
# الورد الدمشقي
# فريزيا
# الياسمين
# الأخشاب
# الأناناس
# البرغموت
# ليمون صقلية
# الفاوانيا
# كشمش أحمر
# البنفسج
# خشب الصندل
# حبوب التونكا
# كاراميل
# فانيلا
# زهر البرتقال
# يلانغ يلانغ
# الخوخ
# البرغموت
# الألدهيدات
# الياسمين الطازج
# زنبق الوادي
# زهر السوسن
# الورد
# خشب الصندل
# نجيل الهند
# الطحلب
# الباتشولي
# بوربون الفانيليا
# المسك
# نجيل الهند
# العنبر
# ورق التين
# جوز الهند
# إبر الصنوبر
# البطيخ
# الهيل
# البرجموت
# الليمون
# الجالبانوم
# التفاح
# القطيفة
# العنبر
# الباتشولي
# خشب الأرز
# المسك
# نجيل الهند
# الفانيليا
# الباتشولي
# العنبر الجاف
# المسك
# الزهور البيضاء
# الهيل
# الزعفران
# الكشمير
# نجيل الهند
# البخور
# زيت الباتشولي
# الجلود
# راتنجات ستيراكس
# السرو
# اللابدانوم
# أوراق البنفسج المصري
# البردقوش
# الماندرين
# الجريب فروت
# الفلفل الأسود
# الفلفل الوردي
# القرفة
# الفانيليا
# التمر
# الورد
# الفريزيا
# الليتشي
# توت العليق
# زنبق الوادي
# الياسمين
# الليلك
# الفاوانيا
# الزنبق
# المسك
# الباتشولي
# تفاح
# ليمون حلو
# توت أسود
# الجلود
# العود
# الباتشولي
# نجيل الهند
# إبرة الراعي
# البرجموت
# الهيل
# الكمون
# الزعفران
# التوت المثلج
# المشمش المجفف
# المسك
# البنفسج
# الياسمين
# الورد
# الصنوبر
# الأزهار
# نجيل الهند
# الجلود
# الأخشاب
# اللبان
# العنبر
# الصمغ
# زهور البرتقال
# العسل
# الماندرين
# البرجموت
# الفلفل الوردي
# اليوسفي
# برتقال حلو
# سفرجل
# راوند
# فلفل أسود
# زنجبيل
# ياسمين
# لوز
# خشب الأرز
# مكونات خشبية
# عنبر
# فانيليا
# مسك
# أخشاب العود
# الجلود
# طحلب البلوط
# الفلفل الأسود
# الجلبانوم
# أخشاب الأرز
# الحبوب الدقيقة
# البرجموت
# السرو
# اللافندر
# العود
# أخشاب الصندل
# القرفة
# الزعفران
# القرنفل
# اللابدانوم
# التفاح
# الحمضيات
# الباتشولي
# العنبر
# قشر الكاكاو
# المسك
# زهور البرتقال
# المارشميللو
# الألدهيدات
# الياسمين
# زنبق الوادي
# الفانيليا
# المسك
# ياسمين سامباك
# مسك الروم
# زهر البرتقال
# البرغموت
# اللبان
# الحوجري
# الورد
# الناضج
# القرفة
# أخشاب
# الصندل
# الباتشولي
# العنبر
# الأخشاب
# الفلفل
# الباتشولي
# حبوب التونكا
# الورد
# الياسمين
# البرجموت
# المسك
# الهيل
# الماندرين
# المسك
# الورد
# التوابل
# اخشاب الصندل
# العود
# الباتشولي
# السويدي
# المسك
# أخشاب الصندل
# اللابدانوم
# الورد
# البنفسج
# القرفة
# الزعفران
# البرجموت
# نجيل الهند
# المسك
# الباتشولي
# الأرز
# الفانيليا
# العنبر
# أخشاب الصندل
# العود
# الماجنوليا
# الورد
# الياسمين
# زنبق الوادي
# البنفسج
# زبدة السوسن
# الماندرين
# الكسبرة
# النيرولي
# الإيلنغ
# العنبر الجاف
# المسك
# الصندل
# البنفسج
# المريمية
# الصنوبر
# البرجموت
# الليمون
# الريحان
# ليمون سيسيليا
# زهرة الينسون
# العرق سوس
# النعناع
# اللاڤندر
# زهور إبرة الراعي
# الإيلنغ
# المجنوليا
# الكزبرة
# الكمون
# المسك
# زنبق
# الوادي
# الماندرين
# المسك
# خشب الصندل
# طحلب البلوط
# اللافندر
# لويزة الليمون
# القرفة
# الفلفل
# القرنفل
# الليمون
# العنبر
# الفانيليا
# اللبان
# الزعفران
# الفانيليا
# الفلفل الأسود
# إليمي
# الطحالب
# أخشاب الصندل
# العنبر
# الفانيليا
# الياسمين
# الورد
# السوسن
# اللافندر
# النخيل
# ماء جوز الهند
# المسك
# حلوى اللوز
# أخشاب الغاياك
# بربون
# الفانيليا
# القرفة
# الهيل
# زهور البرتقال
# البارغموت
# المريمية
# الجريب فروت
# الياسمين و الفاوانيا
# اللوز
# الأخشاب
# الباتشولي
# بنزوين - الجاوي
# المسك
# عبير البودر
# الورد
# الفانيليا
# القرنفل
# العرعر
# أخشاب الغاياك
# الباتشولي
# اللبان
# الكراوية
# سيبروس
# اللابدانوم
# نوتات
# خضراء
# البرجموت
# الشيح
# الكشمش الأسود
# توت العليق
# الكمثرى
# البرتقال
# البرغموت
# الوردة البلغارية
# الفاوانيا البيضاء
# الفريزيا
# زهرة الداتورة
# جوهر الباتشولي
# الجاوي
# الكشمير
# المسك الأبيض
# نجيل الهند
# الباتشولي
# الأرز
# الفانيليا
# الورد
# الإيلنغ
# زهور التبغ الأبيض
# زهور البرتقال
# البرجموت
# الماندرين
# البرتقال المر
# العسل
# الجلود
# المسك الأبيض
# التبغ
# الياسمين
# أخشاب الأرز
# نجيل الهند
# الزعفران
# اليوسفي
# الشاي الأسود
# أوراق الغارورق
# الفلفل الوردي
# كشمش أحمر
# زهرة اللوتس
# ورد
# العنبر
# باتشولي
# المسك
# فانيلا
# أخشاب الصندل
# المر
# الفانيليا
# الياسمين
# جوز الهند
# الإيلنغ
# النيرولي
# البرجموت
# الجير
# العنبر
# الجلد
# الفانيليا
# البنزوين
# اللابدانوم
# نجيل الهند
# توت العرعر
# كشمش أسود
# تفاح
# فلفل وردي
# أرز
# ياسمين
# زيت سيبريول أو ناجارموثا
# زنبق الوادي
# ورد
# الجريب فروت
# الليمون
# البرغموت
# الزعتر
# الجلبانوم
# الشيح
# العنبر
# نجيل الهند
# أخشاب الأرز
# أخشاب الصندل
# الصنوبر
# المريمية
# الأوراق الخضراء
# ريحان
# ياسمين
# حمضيات
# شيح
#  نجيل الهند
#  الورد
# الباتشولي
#  طحلب البلوط
#  العنبر
# المسك
# حبوب التونكا
# الفانيليا
# الأخشاب الغريبة
# العنبر
# الجلود
# التبغ
# الباتشولي
# الزميل
# اللابدانوم
# زهرة الخلود
# نجيل الهند
# التبغ
# الزميل
# الماندرين
# الأزهار
# الحمضيات
# التوابل
# الباتشولي
# المسك
# العود
# جوزة الطيب
# الزعفران
# اللافندر
# اللابدانوم
# أخشاب الصندل
# الفانيليا
# الورد
# الباتشولي
# حبوب التونكا
# البنفسج
# اللوز المر
# أملاح البحار
# الفواكه
# البرجموت
# الليمون الصقلي
# السوسن
# الماندرين
# نسمات البحار
# الأخشاب
# المسك
# أخشاب الصندل
# الفانيليا
# المسك
# أخشاب العود
# العنبر الجاف
# الأناناس
# البرجموت
# الزعفران
# التفاح
# العسل
# الورد
# ياسمين سمباك
# الماجنوليا
# الطاقة الشمسية
# برجموت كالابريا
# الماء
# زهور البرتقال
# قلب نجيل الهند
# أمبروكسان
# كشميران
# المسك
# ياسمين سمباك
# هيلونال
# السوسن المركز
# الفلفل الوردي
# بطيخ جاليا
# وندكافيرتول
# أخشاب الصندل
# البنزوين
# حبوب التونكا
# المسك
# الفانيليا
# الخوخ
# الورد
# المشمش
# زنبق الوادي
# الفاونيا
# السوسن
# الحمضيات
# التوابل
# الأخشاب
# العود
# الورد
# الزعفران
# الأخشاب
# الجافة
# الثمينة
# البرغموت
# توت العرعر
# الجير
# الفلفل الوردي
# أوراق الحمضيات
# كلاري ساج
# ماغنوليا
# زهر البرتقال
# هيديون
# نجيل الهند
# العنبر البلوري
# الباتشولي
# الخشب الأبيض
# المسك
# البخور
# الورد
# الباتشولي
# برتقال سيسيلي
# برغموت كالابريا
# ليمون
# ورد
# ياسمين
# رائحة الفواكه
# باتشولي
# التونكا
# فانيليا مدغشقر
# عدان
# مسك أبيض
# الشاي الأسود
# البرغموت
# أوراق البنفسج
# الماغنوليا
# الياسمين المصري
# الورد
# زهر البرتقال التونسي
# الباتشولي
# خشب الصندل
# العود الكمبودي
# فول التونكا
# المسك الأبيض
# العنبر
# أطلس سيدار
# فيرجينيا سيدار
# الألدهيدات
# جوزة الطيب
# فلفل اسود
# الأوزون
# نجيل الهند الهايتي
# كالابريا البرغموت
# الأزهار
# الباتشولي
# الياسمين
# الكحول
# عطر
# ماء
# ألفا-أيزو ميثيل أيونون
# ساليسيلات البنزيل
# هيدروكسي سيترونيلال
# ليمونين
# غيرانيول
# بولي إيثيلين جليكول ٤۰ زيت خروع مهدرج
# كومارين
# سيترونيلول
# إيزوجينول
# بنزوات البنزيل
# كحول بنزيلي
# الليمون
# الريحان
# كلاري سيج
# الأوريجانو
# قرنفل
# باتشولي
# قرفة
# إبرة الراعي
# القندس
# طحلب البلوط
# العنبر
# اللابدانوم (الروكروز)
# المسك
# الورد
# المسك
# خشب الصندل
# العنبر
# أخشاب الأرز
# الباتشولي
# حبوب التونكا
# زهور البرتقال
# الورد الدمشقي
# المسك
# الفلفل الوردي
# الياسمين
# الزهور البيضاء
# البرجموت
# الكشمش الأسود
# اليوسفي
# أرتميسيا
# زهور الخوخ
# الياسمين
# الورد
# الفانيليا
# المسك
# نجيل الهند
# الباتشولي
# زهرالبرتقال
# المندرين الأخضر
# المسك
# الورد
# الاوكيموس
# العنب الأسود
# الأخشاب
# الفانيليا
# البلسم
# التوابل
# العنبر
# الجوز
# المسك
# برغموت كالابريا
# الجريب فروت
# أوراق التين
# أوراق البنفسج
# خشب البردى
# الباتشولي العضوي
# الفلفل الأسود
# أمبروكس
# المسك المعدني
# حبوب التونكا
# البخور
# الزعفران
# تفاح
# فاكهة النجمة
# بطيخ
# إجاص,ورد بلغاري
# بنفسج
# زهرة يلانغ يلانغ
# ياسمين
# مسك الروم الهندي
# خوخ
# قرنفل
# جوزة الطيب,عنبر
# سوسن
# مسك التبت
# خشب الصندل
# فانيليا
# أخشاب الصندل
# المسك
# جذور السوسن
# زنبق الوادي
# الورد
# الفريزيا
# زهور البرتقال
# الياسمين
# الجاردينيا
# مسك الروم
# اللافندر
# البرجموت
# البرتقال
# روائح عشبية
# مسك الروم
# الفل
# صريمه الجدي
# جذور السوسن
# خشب الصندل
# الفانيلا
# الحمضيات
# التفاح الأخضر
# زهور إبرة الراعي
# القرفة
# خشب الأرز
# خشب الصندل
# أخشاب
# دريفت
# الشاي
# نوتات
# مائية
# العود
# العنبر
# الفلفل
# الجلود
# الورد
# العنبر
# الأرز
# الهيل
# الزنجبيل
# أوراق الباتولا
# اللافندر
# الجريب فروت
# الليمون الإيطالي
# النعناع
# أخشاب الصندل
# حبوب التونكا
# مسك الجلود
# زيت ياسمين سمباك
# زهر اللوز
# زيت الماندرين
# الفشار الوردي
# الكرز الخصب
# الفاوانيا الحمراء
# الفانيليا
# نجيل الهند
# الباتشولي
# العنبر
# الأخشاب
# الزنجبيل
# اللافندر
# التبغ
# المريمية
# الجريب فروت
# الكاكاو
# أخشاب الصندل
# أخشاب الغاياك
# سيبريول
# الفانيليا
# العنبر
# حبوب التونكا
# العود
# الجريب فروت الأخضر
# الزعفران
# قشر البرتقال
# إيلمي
# البرغموت
# زعفران
# الياسمين
# ورد وقرنفل
# العنبر
# القُرّيضة
# العود ومر
# الليمون
# الماندرين
# أوراق البنفسج
# زهرة اللوتس
# الياسمين
# المسك
# خشب العنبر
# زيت الأوريس
# زيت خشب الأرز
# أخشاب الأرز
# القريضة
# الباتشولي
# اللافندين
# سيبريول
# رذاذ بحري
# الفلفل الأسود
# الهيل
# اليوسفي
# خشب الغاياك
# الجاوي
# الأرز
# فانيليا مدغشقر
# الخزامى
# إبرة الراعي
# الياسمين
# القرفة
# الليمون
# الماندرين الأصفر
# الفانيليا
# المسك
# الفلفل الوردي
# الخوخ
# زهور
# البرتقال
# أخشاب العنبر
# طحلب البلوط
# المسك الأبيض
# الأوركيد الأسود
# الياسمين
# اخشاب الأرز
# توت العليق
# الأناناس
# الكسبرة
# الورد الأبيض
# زنبق الوادي
# هيليوتروب
# البنفسج
# خشب الأرز
# المسك الابيض
# العنبر
# الباتشولي
# أخشاب الصندل
# البنزوين
# الورد الدمشقي
# الماغنوليا
# ياسمين سمباك
# الياسمين
# الفلفل الأسود
# البرجموت
# الماندرين الإيطالي
# أخشاب الغاياك
# المسك
# أمبروكسان
# الياسمين المصري
# الأوراق الخضراء
# كشميران
# الزهور
# برتقال الدم الزغلول
# فلفل سيشوان
# الفلفل الوردي
# الزنجبيل
# البرجموت
# أخشاب الصندل
# العود
# الجلود
# العنبر
# الزعفران
# الأرز
# أخشاب الغاياك
# أوراق البنفسج
# البرجموت
# البرتقال
# التفاح
# الزنجبيل
# العود
# المسك
# الأبيض
# الورد
# البارغموت
# الشاي
# الأوثامنتوس
# الياسمين
# زهرة البرتقال الأفريقي
# فريزيا
# الورد والأوركيدا
# المسك والباتشولي
# نجيل
# الهند
# الزنجبيل
# المريمية
# الفانيليا
# المسك الأبيض
# أخشاب الكاشمير
# الورد
# الباتشولي
# الفلفل الوردي
# الألدهيدات
# الورد الفارسي
# والبتولا الجاف
# والياسمين الهندي
# والباتشولي
# و طحلب البلوط الأساسي
# والمسك
# والعنبر
# و الفانيليا
# الفانيليا
# الأخشاب
# الفواكه
# تفاح
# روائح فاكهية,برقوق
# زهرة الفريسيا
# زنبق الوادي
# زهرة الأوركيد
# ورد
# بنفسج
# ياسمين
# مسك الروم,توت العلّيق
# فانيليا
# خشب الأرز
# مسك
# الزعفران
# أوليبانوم
# الورد
# خشب الصندل
# المسك الأبيض
# الرمان
# الكشمش الأسود
# الفاونيا
# الياسمين الليلي
# المسك الأبيض
# الفانيليا
# ايزو آي سوبر
# بلسم بيرو
# أخشاب الأرز
# الجلود
# حبوب الهيل
# هديون
# جوزة الطيب
# الأعشاب العطرية
# الفلفل الوردي
# الليمون
# برجموت كالابريا
# الحمضيات
# العرعر
# الصنوبر
# البرجموت
# المريمية
# التنوب
# الباتشولي
# الجلود
# لبادنوم
# الياسمين
# القهوة
# الفانيليا
# الباتشولي
# نجيل الهند
# نوتات معدنية
# إبرة الراعي
# اللافندر
# المريمية
# الماندرين الأخضر
# رذاذ البحر
# أخشاب الباتولا
# العود
# الفانيليا
# جلد الغزال
# أخشاب الباتولا
# الياسمين
# الفلفل الوردي
# العنبر
# البرجموت
# التوت البري
# الماندرين
# الورد
# مسك الروم
# عرق السوس
# خشب الصندل
# أخشاب السدر
# نجيل الهند
# الباتشولي
# زهور البرتقال
# الياسمين
# الفلفل الأحمر
# الأناناس
# الماندرين
# كحول دينات
# أكوا
# ماء
# عطر
# ليمونين
# إيثيل هكسيل ميثوكسيسينامات
# لينالول
# بوتيل ميثوكسيديبنزويل ميثان
# إيثيل هكسيل ساليسيلات
# سيترال
# جيرانيول
# سيترونيلول
# توكوفيرول
# الياسمين
# القرنفل
# الفانيلا
# العسل الأبيض
# العطر
# ماء
# بنزيل الساليسيلات
# كحول البنزيل
# بنزوتريازوليل دوديسيل بي كريسول
# أميل سينامال
# ليمونين
# هيكسيل سينامال
# لينالول
# سيترونيلول
# جيرانيول
# كومارين
# ميثيل أنثرانيليت
# بنتاريثريتييل تترا دي تسو بوتيل
# هيدروكسي هيدروجيني هيدروكسي سيترونيلال
# فارنيسو
# المسك
# أخشاب الصندل
# أمبروكسان
# العنبر
# أنجليكا
# أمريس
# الماندرين
# الزنجبيل
# العسل
# الزهور البيضاء
# الكراميل
# الباتشولي
# الأرطماسيا والريحان والزعتر والكمون والكزبرة والقرنفل
# الأخشاب الصنوبرية
# الباتشولي والبلوط ونجيل الهند
# الجلد والتبغ والزعتر
# الباتشولي
# حبوب التونكا
# الفانيليا
# حلوى البرالين
# السوسن
# الياسمين
# زهور البرتقال
# الكشمش الأسود
# الكمثرى
# البارغموت
# الفلفل
# القرنفل
# الخزامى
# روائح عشبية
# الياسمين
# العسل
# بلسم تولو
# المسك
# الفانيليا
# العنبر
# الباتشولي
# البرغموت
# ينسون
# فلفل بوريورن
# لافندر
# زنبق الوادي
# إبرة الراعي
# خشب الصندل
# الباتشولي
# حبوب التونكا
# الزنجبيل الحار
# الفانيلا
# التوابل
# القرفة
# طحلب البلوط
# زهور الباتشولي
# البرجموت
# العنبر
# أخشاب الصندل
# الأرز
# أخشاب
# الأرز
# التبغ
# الباتشولي
# البرجموت
# الورد
# الباتشولي
# العود
# جوز الهند
# الورد
# الليمون
# الألدهيدات
# الزعفران
# الورد
# حشب الصندل
# البرغموت
# الكمثرى
# زهر البرتقال
# الورد
# الهليوتروب
# الفريزيا
# الفانيليا المطلقة
# المسك
# الأخشاب الشقراء
# حبوب التونكا
# حجر الدم
# الشعير
# السوسن
# التين
# الخشخاش
# العنبر
# المسك
# العنبر
# الطحالب
# الياسمين
# أخشاب أكيجالا
# السوسن
# البرجموت
# التوت
# الصنوبر
# اللافندر
# الماندرين
# الأخضر
# العنبر
# التوابل
# نوتات أروماتيك
# العنبر الأبيض
# طحلب السنديان
# الأرز الأبيض
# جوزة الطيب
# هيل جواتيمالا
# الزنجبيل
# الماندرين
# البرجموت
# النعناع
# ينسون
# الباغموت
# الجريب فروت
# أوراق القرفة الصينية
# روائح عشبية
# هديون
# الورد
# المسك الأبيض
# أخشاب الساج
# العنبر
# نجيل الهند
# اللافندر
# زهور البرتقال
# توت العرعر
# البرجموت
# الفلفل الأسود
# التفاح الأخضر
# الماندرين
# الليمون
# الهيل
# الصندل
# دهن العود
# الأخشاب الشقراء
# الباتشولي
# المسك
# المريمية
# ياسمين سمباك
# الماغنوليا
# جوز الهند
# توت العليق
# البرغموت
# الهيل
# البنفسج
# لافندر
# الكافيار
# السوسن
# سيج
# فول التونكا
# أمبروكسان
# التبغ
# البتشولي
# البرغموت (الحمضيات)
# الكمثرى
# الفلفل الوردي
# الورد
# الياسمين
# المسك الأبيض
# الفانيليا
# الباتشولي
# خشب الأرز
# الباتولا
# الفانيليا
# دهن
# عود
# اسام
# الهندي
# الأخشاب
# الحمضيات
# النعناع
# أخشاب الكشمير
# المسك
# الفانيليا
# نجيل الهند
# العنبر
# شجر
# السرو
# اللافندر الفرنسي
# زهور البرتقال
# الأوركيد
# الفانيليا
# الزعفران
# جوزة الطيب
# القرفة
# الجلد المدبوغ
# خشب الصندل
# العود
# العنبر
# الفانيليا
# الفانيليا
# خشب الأرز
# الورد البلغاري
# مسك الروم
# الإيلنغ
# الغردينيا
# خشب الصندل
# ليمونسيلو
# فاوانيا
# كاراميل
# جاوي
# عسل
# مسك
# المسك
# العنبر
# الباتشولي
# النعناع
# التفاح الأخضر
# الليمون
# التونكا
# زهور إبره الراعي
# أمبروكسان
# فانيليا مدغشقر
# نجيل الهند
# طحلب البلوط
# أخشاب الأرز من فرجينيا
# أخشاب الأرز الأطلسي
# الأرز
# حبوب التونكا
# أخشاب الغاياك
# العنبر
# السويدي
# الجلود
# الفانيليا
# الياسمين
# زهور البرتقال
# الورد البلغاري
# كولفي
# الحمضيات
# النيرولي
# الماندرين
# الزنجبيل
# الهيل
# العنبر
# الجلود
# طحلب البلوط
# أخشاب الغاياك
# المسك الأبيض
# الورد البلغاري
# البنفسج
# الباتشولي
# البرجموت
# السيسيلي
# الكشمش الأسود
# البرغموت الإيطالي
# التفاح
# الأناناس
# الورد
# خشب البتولا
# الياسمين المصري
# الباتشولي
# خشب السنديان
# العنبر
# الفانيليا الفرنسية
# الكزبرة
# البرجموت
# الجريب فروت
# الخوخ الأبيض
# الورد
# الياسمين
# الباتشولي
# المارشيمللو
# حبوب التونكا
# الورد
# الماغنوليا
# النيرولي
# النوتات الخضراء
# صريمة الجدي ياسمين سمباك
# الجلد
# تمر هندي
# العنبر
# البلح
# التنوب البلسمي
# الفانيليا
# الكاراميل
# تبن
# اللبان
# استراكس العبهر
# روائح الأعشاب
# العود
# المسك
# أخشاب أكياجالا
# الباتشولي
# نجيل الهند
# الزهور البيضاء
# أوراق البنفسج
# راتنجات إليمي
# الفلفل الوردي
# أصابع الليمون
# المريمية
# البرجموت
# البرجموت
# الورد
# الياسمين
# أخشاب الأرز
# الفانيليا
# الهيل
# الفانيليا
# الياسمين
# البنفسج
# الماندرين
# اللافندر
# العود
# البتولا
# خشب الصندل
# المسك
# الفانيليا
# روائح خشبية
# قهوة
# شحوم
# الراوند
# اليانسون
# البرغموت
# البرغموت
# الليمون
# الخزامى
# الويسكي
# التفاح
# التوابل
# القرفة
# إبرة الراعي
# الفانيليا
# الباتشولي
# المسك الأسود
# الورد المائي
# الورد الأحمر
# الورد
# اللوز
# الشاي الأسود
# المسك الأسود
# الجلود
# البرتقال
# اليوسفي
# البارغموت
# الكمون
# الهيل
# المردقوش
# والجلد
# المسك
# الطحالب
# المسك
# الأخشاب
# العنبر
# الأزهار
# سيبريول
# ناجارموثا
# اخشاب الصندل
# الباتشولي
# اللافندر
# الحمضيات
# البرجموت
# الماندرين الأخضر
# حار كليا,عسل
# ورق الغار
# أوركيد
# ورد
# قرنفل
# بذور الكرفس
# خشب غاياك,بتشول
# جاوشير
# مرمية
# خشب سيدؤ أطلسي
# مسك
# طحلب
# عنبر
# خشب العود
# نبات الكاري
# توت أسود
# أوراق التوت الأسود
# كشمش أسود
# توت العلّيق,كرز حامض
# زهر البرتقال
# تفاح
# كشمش أسود,بتشول
# مسك العنبر
# العنبر
# الباتشولي
# الفانيليا الكريمية
# الياسمين
# الورد الأحمر
# نجيل الهند
# البرجموت
# الموجيت
# الفواكه المائية الفوارة
# خشب الصندل
# العنبر
# الفانيليا
# الباتشولي
# القرفة
# الورد
# إبرة الراعي
# اللافندر
# البرتقال
# المسك
# العنبر
# كشميران
# زنبق الوادي
# الياسمين
# الورد
# التفاح
# الكشمش الأسود
# الليمون
# إكليل الجبل
# أناناس
# زهر البرتقال
# برغموت
# ليمون,لبان
# خشب الصندل
# بتشول,عنبر
# روائح خشبية
# جاوي
# الجريب فروت
# مياه البحار
# أوراق الخليج
# إبرة الراعي
# التوابل
# أخشاب الغاياك
# العنبر
# الفراولة
# الفاوانيا
# الورد
# زنبق الوادي
# العنبر
# نجيل
# الهند
# اللافندر
# البرجموت
# الليمون
# والشاي
# الهندي
# وخشب
# الصندل
# فلفل وردي
# زعفران
# قرفة
# جوز الطيب
# ورد
# ياسمين مصري
# عشبة دافانا
# ليذر
# نجيل الهند
# خشب جاياك
# باتشولي
# سيبريول
# توباكو
# فانيليا
# بخور
# عنبر
# مسك
# يوسفي أخضر
# فلفل أسود
# ورق البتولا,فرانجيباني
# ياسمين
# زهر البرتقال,مسك
# فانيليا
# خشب الأرز
# بتشول
# حبوب التونكا
# العنبر الجاف
# الفانيليا
# الباتشولي
# أخشاب السدر
# أخشاب الصندل
# البرجموت
# الزعفران
# السينابون
# الريحان
# البرتقال
# النعناع
# البرغموت
# التفاح الأخضر
# اللافندر
# الهيل
# المريمية
# المسك
# خشب الصندل
# العنبر
# الكراميل
# حبوب التونكا
# البرجموت
# العنبر
# بربون
# الفانيليا
# الأخشاب
# الزنجبيل
# الورد
# زنبق الوادي
# البنفسج
# زهور البرتقال
# الياسمين
# زهر البرتقال
# الليمون
# إكليل الجبل
# جوزة الطيب
# الكزبرة
# الخزامى
# إبرة الراعي
# الهيل
# الليتشي
# فول التونكا
# خشب الساج
# نجيل الهند
# Rosemary
# lavender
# vanilla
# musk
# العنبر
# المسك الأبيض
# التبغ
# أخشاب الغاياك
# الفانيليا
# نجيل الهند
# خشب الصندل
# الياسمين
# الباتشولي الدافئ
# العود
# الزعفران
# التفاح الأخضر
# القرفة
# البخور
# الكمثرى البيضاء
# جوزة الطيب
# أخشاب الصندل
# المسك
# البنفسج
# البرجموت
# الماندرين
# الكمثرى
# سيبرول
# الباتشولي
# كسرات العود الخشبي
# الورد التركي
# القرنفل
# التفاح
# الفلفل الوردي
# إكليل الجبل
# أوراق البنفسج
# الجالبانوم
# زهر العسل
# النفحات الخشبية
# الماغنوليا
# اليوسفي الصقلي
# الفاوانيا
# الفلفل الوردي
# ورد
# ياسمين سامباك
# زهرة يلانج يلانج
# نبات البردي
# العود
# باتشولي
# حبوب التونكا
# الفلفل الوردي
# الزعفران
# الورد
# السوسن
# الفانيليا
# العنبر
# المسك
# الباتشولي
# المسك
# الفانيليا
# الأرز
# العنبر
# البتشولي
# الأرز
# البرالين
# جوزة الطيب
# البرجموت القرفة
# القهوة
# الهيل
# العنبر الأبيض
# الأخشاب
# الباتشولي
# زبدة السوسن
# المسك الأبيض
# حجر الدم
# الورد التركي
# حشائش الوردي
# السوسن
# الفلفل الوردي
# الليتشي
# بتلات السوسن
# البرغموت
# الماندرين
# الإيلنغ
# التوت
# الفاوانيا البيضاء
# أوسمانثوس
# خشب الأرز
# الباتشولي الأبيض
# أمبروكس
# الأخشاب
# اللافندر
# زنبق الوادي
# أخشاب الصندل
# دهن العود الكلاسيكي
# النعناع
# البرغموت
# ليمون أمالفي
# الأرز
# الكزبرة
# السرو
# أوكالبتيوس
# التوابل
# أوبوبوناكس
# القرفة
# البازلاء الحلوة
# البرغموت
# الماندرين
# الجريب فروت
# الليمون
# باشن فروت
# الخوخ
# الغردينيا
# الباتشولي
# الورد
# حبوب التونكا
# بربون الفانيليا
# التبغ
# الأرز الأبيض
# الحبوب الدقيقة
# الفلفل الوردي
# الليمون
# سيترون
# البرجموت
# دينات الكحول (كحول إس دي 39-سي)
# عطر
# أكوا
# ماء
# ألفا إيزوميثيل أيونون
# بنزيل ساليسيلات
# كحول سيناميل
# سيترال
# سيترونيلول
# كومارين
# ليمونين
# لينالول
# الماندرين
# الجريب فروت
# الكشمش الأسود
# مسك الروم
# يلانغ يلانغ
# الياسمين
# زهر البرتقال
# خشب الصندل
# مسك الروم
# عسل أبيض,ورد بلغاري
# سوسن,بتشول
# جلد
# فانيليا
# حبوب التونكا
# أخشاب الصندل
# المسك
# حجر الدم
# إبرة الراعي
# الفاونيا
# الكشمش الأسود
# الليتشي
# اليوزو
# البرغموت
# الخشخاش الأحمر
# الكاميليا
# الزنجبيل
# النرجس
# الورد
# حجر الدم
# المسك
# السوسن
# الخوخ
# اليوسفي
# أوراق البنفسج
# أزهار البرتقال
# الهليوتروب
# الياسمين
# خشب الصندل
# الفانيليا
# حبوب التونكا
# الطحالب
# السويدي
# الأخشاب النقية
# اللافندر
# المريمية
# الزنجبيل
# الفلفل الوردي
# البرغموت
# الجريب فروت
# أخشاب الأرز
# نجيل الهند
# الجاوي
# القندس
# اللابدانوم
# بلسم التنوب
# الفانيليا
# توت العليق
# حبوب التونكا
# إبرة الراعي
# زهور البرتقال
# الورد
# الزعتر
# الجلود
# أوراق البنفسج
# الألدهيدات
# الزعفران
# البرجموت
# اللوز
# الهيل
# أوراق الأرز
# الباتولا
# الفانيليا
# المسك
# العنبر
# جوزة الطيب
# الباتشولي
# الليمون
# الزعفران
# الورد
# الكشمش الأسود
# برقوق
# خضروات
# تفاح
# الورد
# القرنفل الأبيض
# البرجموت
# الليمون
# أرز فيرجينيا
# خشب الصندل
# الجريب فروت
# الجريب فروت
# أوراق البنفسج
# الأناناس
# إبرة الراعي
# المريمية
# التفاح
# الباتشولي
# الطحلب
# أخشاب الكاشمير
# العود
# الجريب فروت
# اليانسون
# اللافندر
# التوت
# الأخشاب
# الهليوتروب
# البارغموت
# ثمار التين
# اليوسفي الأخضر
# الحمضيات
# الكمثري
# الزنبق
# الياسمين
# الحبهان
# النرجس
# خشب الصندل
# أخشاب الأرز من فرجينيا
# أشجار الزيتون
# المسك
# المسك
# الفانيليا
# نجيل الهند
# أخشاب الأرز
# أخشاب الصندل
# البرجموت
# الزعفران
# البرغموت
# ماء الورد
# خلاصات زهريّة
# باتشولي
# مر
# العنبر
# العنبر
# الجلود
# الفانيليا
# الورد
# الزعفران
# البخور
# زهور البرتقال
# إليمي
# الفلفل الأسود
# السَفَرْجَل
# البرقوق والياسمين
# الورود البلغارية
# خشب الأرز والعود
# العنبر
# فانيلا وأخشاب الكشمير
# مسك الروم
# نبات إبرة الراعي
# الياسمين
# الزنبق
# التوابل
# الفلفل
# الزنجبيل
# الزعفران
# نجيل الهند
# زيت سيبريول
# حبوب التونكا
# تولو بلسم
# ستراكس
# بريش
# اللبان الفرنسي
# العود
# المسك
# العنبر
# حبوب التونكا
# نجيل الهند
# الباتشولي
# أخشاب الغاياك
# التبغ
# الجريب فروت
# الزعتر
# إكليل الجبل
# الحمضيات
# الزعفران
# التوابل
# أوسمانثوس
# العرعر
# الريحان
# النعناع
# الياسمين
# التوت الأسود
# اللوتس
# العنبر
# العسل
# الزعفران
# زهور البرتقال
# حبوب التونكا
# اللوز
# الفانيليا
# المر
# اللافندر
# نجيل الهند
# أوراق الباتشولي
# الجلد
# العود
# الحمضيات
# القرفة
# الورد
# الخشب
# الخزامى
# المسك الأبيض
# نفحات بحرية
# البخور
# مسك الروم
# الزنجبيل
# الياسمين
# الطحلب
# اللبان
# خشب الأرز والباتشولي
# الكمثرى
# البرغموت
# اليوسفي
# الفانيليا
# الوردة السوداء
# الفراولة
# الباتشولي
# بخور البردي
# الليتشي
# برالين
# الفانيليا
# الكراميل
# القهوة
# الكومارين
# كحول
# عطر
# أكوا (ماء)
# لينالول
# بوتيل ميثوكسيديبنزويل ميثان
# توكوفيريل أسيتات
# ليمونين
# جيرانيول
# العنبر
# الأخشاب
# الفانيليا
# المسك
# مسك الروم
# الياسمين
# الجاردينيا
# الإيلنغ
# الفانيليا
# العود
# الفانيليا
# أخشاب الصندل
# الباتشولي
# الياسمين
# العنبر
# أخشاب الأرز
# البرجموت
# زهر البرتقال
# العنبر
# العود
# نجيل
# الهند
# أخشاب الأرز
# التبغ
# الماندرين
# جذور السوسن
# الفلفل الأسود
# الفلفل الوردي
# الفلفل الأحمر
# المر
# زهور إيجلنتين
# الكستناء
# نجيل الهند
# أخشاب الغاياك
# التوابل
# العنبر
# البرجموت
# الماندرين
# حبوب
# التونكا
# الفواكه الاستوائية
# قصب السكر
# التين
# النوتات الخضراء
# الليمون
# الأخضر
# أخشاب الكشمير
# فول التونكا
# الباتشولي
# باشن فروت
# التين
# الفاوانيا
# مسك الروم
# الكمثرى
# الماندرين
# البرغموت
# الفانيليا
# العود
# المسك
# الورد
# البرالين
# الفواكه الحمراء
# الفلفل الوردي
# الزعفران
# الجلود
# أخشاب الغاياك
# الفانيليا
# الورد
# السوسن
# الزعفران
# كشمش الأسود
# حبوب التونكا
# المسك الأبيض
# الأرز
# الفانيليا
# ياسمين سمباك
# جوز الهند
# مسك الروم
# القرفة
# القهوة
# البندق
# الورد
# يلانغ يلانغ
# هديون
# الهليوتروب
# الفانيليا
# اللوز
# البرجموت
# المريمية
# مسحوق أخشاب الأرز
# كحول
# عطر
# أكوا
# ماء
# ليمونين
# لينالول
# بوتيل ميثوكسيديبنزويل ميثان
# ألفا إيزوميثيل أيونون
# كومارين
# سيترونيلول
# سيترال
# جيرانيول
# بينتيريثريتيل
# تترا دي تي بوتيل هيدروكسي هيدروكسينامات
# بنزيل بنزيلوات
# (فارنيسول)
# أخشاب الأرز
# الباتشولي
# العنبر
# قشر الفانيليا السوداء
# الكراوية
# المريمية
# القرفة
# الليمون
# البرجموت
# النعناع
# اللافندر
# الكمثرى
# الورد
# اخشاب العود
# العنبر
# كحول
# عطر
# ليمونين
# أكوا
# بوتيل ميثوكسيديبنزويل ميثان
# إيثيل هيكسيل ميثوكسيسينامات
# سيترال
# لينالول
# بنزيل بنزوات
# المسك
# أوسمانثوس
# الياسمين
# الهندي
# دينات الكحول
# عطر
# أكوا
# ماء
# ألفا-إيزوميثيل أيونون
# بنزيل الكحول
# بنزيل سينامات
# بنزيل الساليسيلات
# سيناميل الكحول
# سيترال
# سيترونيلول
# يوجينول
# أيوجينول
# زنجبيل
# حبهان
# قرفة
# البارغموت
# اليوسفي
# الياسمين
# زهرة البرتقال
# الايلنغ
# نبات الوزال
# المريمية
# عدان فرنسي
# العنبر
# الفانيليا
# الاخشاب
# العنبر
# الفانيليا
# زهور البرتقال
# اللافندر الأزرق
# اللافندر
# الماندرين البرتقالي
# البرجموت
# الألدهيدات
# الزنجبيل الأحمر
# التوت العرعر
# السدر
# حب الهيل
# مكونات خشبية
# أوسمانثوس
# شجرة التنوب
# حبوب التونكا
# نجيل الهند
# العنبر
# المسك
# العنبر
# أخشاب الصندل
# الماجنوليا
# نجيل الهند
# الفلفل
# الماندرين البرتقالي
# البرجموت
# توت العليق
# أخشاب الصندل
# الرم
# شعر
# البنات
# البرجموت
# الأناناس
# أوراق الغار والليمون
# الكشمير
# السوسن
# الياسمين
# العنبر والجلود والمسك
# نجيل الهند
# الفانيليا
# حبوب التونكا
# الكراميل
# العنبر
# زهور الزنجبيل
# الرمان
# الفلفل الوردي
# القهوة
# الفانيليا
# الباتشولي
# أخشاب الأرز
# المسك
# الزهور البيضاء
# الياسمين
# الفلفل الوردي
# زهر البرتقال
# الكمثرى
# الفانيليا
# الباتشولي
# المسك
# العنبر
# نجيل الهند
# السوسن
# الفلفل الوردي
# الياسمين
# الفواكه
# الأناناس
# الصفير
# الألدهيدات
# كحول دينات
# عطر (عطور)
# أكوا (ماء)
# لينالول
# ليمونين
# بوتيل ميثوكسي ديبينزويل ميثان من أصل نباتي 80٪ حجم
# البرغموت
# الحبهان
# اليانسون
# زهور إبرة الراعي
# البخور
# الخزامى
# الطحلب
# الباتشولي
# نجيل الهند
# البرتقال الحمضي
# الورد
# الباتشولي
# الفانيليا
# البرغموت
# واللوز
# ومسك
# الروم
# وزهر
# البرتقال
# والعنبر
# وخشب
# الصندل
# والفانيليا
# المسك
# أخشاب الصندل
# العود الأزرق
# الزعفران
# الورد الطائفي
# دينات الكحول
# عطر (عطر)
# أكوا (ماء / ماء)
# سيترال
# جيرانيول
# ليمونين
# لينالول
# خشب الصندل
# الأمبروكسان
# البخور
# نجيل الهند
# خشب الأرز
# البرغموت
# الياسمين
# برغموت
# هيل
# زعفران
# كمون
# إبرة الراعي
# باتشولي
# عود
# جلد
# نجيل الهند
# مسك
# أخشاب الصندل
# العود
# حبوب التونكا
# الفلفل الأسود
# الزعفران
# جوزة الطيب
# البرجموتـ البرقوق
# جوز الهند
# البرغموت
# التانجرين اليوسفي
# النكتارين
# الكشمش الأسود
# التفاح العصري
# الغاردينيا
# الياسمين
# المغنوليا
# زنبق الوادي
# الفريزيا
# الباتشولي
# المسك
# خشب الصندل
# الفانيليا
# العنبر
# البرغموت
# هيليوتروب
# جذر السوسن
# الفانيليا
# البنزوين
# المسك
# أفسنتين
# أكليل الجبل
# ليمون حلو
# ليمون صقلي
# أوراق التبغ
# الفانيليا
# ستيراكس
# مسك الروم
# نجيل الهند
# المريمية
# الفلفل الوردي
# النيرولي
# الليمون
# فاكهة الكرز
# أزهار (الزنبق)
# ورد
# مسك
# الخزامي
# إكليل الجبل
# النيرولي
# البيتيتغرين
# إبره الراعي
# المريمية
# الغلابانوم
# الياسمين
#  طحلب البلوط (طحلب السنديان)
# نجيل الهند
# خشب الأرز
# خشب الصندل
# العنبر
# الكمثرى
# الكشمش الأحمر
# البرتقال الماندرين
# الياسمين
# فريزيا
# زنبق الوادي
# البرالين
# خشب الصندل
# العنبر
# الأزهار
# الفواكه
# العنبر
# جوز
# الهند
# الماجنوليا
# المسك
# أخشاب الصندل
# الحمضيات
# العنبر
# حجر الدم
# زنبق الوادي
# المسك الأبيض
# الخوخ
# التوت
# القرفة الصينية
# أمبروكسان
# أخشاب الصندل
# الباتشولي
# السوسن
# الورد
# الياسمين
# زهور البرتقال
# الماندرين
# البرجموت
# العنب الأسود
# الزعفران
# أخشاب الصندل
# الفانيليا
# جوزة الطيب
# اللافندر
# اللبان
# الهيل
# الورد
# الزعفران
# الفانيليا
# العنبر
# البتشولي
# المسك
# العنبر
# أخشاب الكشمير
# الكشمش الاسود
# الكريمة المخفوقة
# المارشميللو
# ياسمين سمباك
# صريمة الجدي
# فرانجيباني
# البرجموت
# الكمثرى
# التوت الأحمر
# زهرة الكرز الياباني
# زهرة البنفسج
# المسك
# القرفة
# اللافندر
# أخشاب الورد
# زنبق الوادي
# الأرز
# الورد البلغاري
# المسك
# العنبر
# الفانيليا
# عود تايلاند
# أخشاب الصندل
# العود اللاوسي
# أخشاب الصندل
# الفانيليا
# العنبر
# الجاردينيا
# الياسمين
# الكمثرى
# التوت
# البرجموت
# الأخشاب
# المسك
# العنبر
# الورد
# العود
# الجاوي
# البنفسج
# الفانيليا
# الورد البلغاري
# الألدهيدات
# القرنفل
# الورد
# الزهور
# اللبان
# العنبر
# المسك
# الفانيليا
# دهن العود
# الليمون
# مسك الروم
# الورد
# الخوخ
# الباتشولي
# الأرز
# العنبر
# نجيل الهند
# حليب المسك
# العنبر
# المسك
# الباتشولي
# الورد
# مسك الروم
# الإيلنغ
# الياسمين
# الفواكه
# الفلفل الوردي
# الفلفل الوردي والبخور وجوزة الطيب
# الجاردينيا والإيلنغ والخوخ
# الباتشولي وخشب الصندل والعنبر
# زنبق الوادي
# العنبر
# البارغموت
# اليوسفي
# فلفل سيتشوان
# الباتشولي
# نجيل الهند
# الخزامى
# زهور إبرة الراعي
# العنبر
# المسك الأبيض
# توت العرعر
# البرغموت
# الفلفل الأبيض
# إبرة الراعي
# الياسمين
# خشب الكشمير
# المسك
# الباتشولي
# والأرز
# ليمون حلو,جوز طيب
# فلفل
# لبان,إيفرينا خوخية
# قريضة
# مسك
# خشب الصندل
# نجيل الهند
# سيدر
# الفلفل الوردي
# الماندرين الأصفر
# البرغموت
# روائح حلوة
# نفحات فاكهية
# ياسمين سامباك
# ورد مغربي
# الباتشولي
# العنبر
# المر
# البخور
# البنزوين والجلد
# خشب الورد البالي
# الخزامى
# القرفة
# الورد البلغاري
# خشب الأرز
# زنابق الوادي
# العود اللاوسي
# العود التايلاندي
# خشب الصندل
# المسك
# الفانيليا
# العنبر
# الياسمين
# أوسمانثوس
# البنزين
# المشمش
# برغموت
# فلفل وردي
# هيديون
# ورد بلغاري
# ورد تركي
# ياسمين مصري
# فانيلا
# عنبر
# التبغ
# التوابل
# العنبر
# الأزهار
# جذور السوسن
# الألدهيدات
# البودرة
# الماندرين
# الليمون
# البرجموت
# البرقوق الأصفر
# الورد
# الخوخ
# الياسمين
# الفريزيا
# المسك الأبيض
# خشب الصندل
# الباتشولي
# أخشاب العنبر
# طحلب البلوط
# Woods
# Iris
# Musk
# Lemon
# Amber
# برغموت
# برتقال مر
# برتقال حلو
# ليمون
# ياسمين
# خشب الأرز
# فلفل وردي
# بابريكا
# الليمون
# البرغموت
# الزعفران
# الورد التركي
# الجوهر المطلق
# زهرة الغرنوقي
# يلانغ يلانغ
# المر
# خشب الصندل
# باتشولي
# الستراكس
# البخور
# النجارمثا
# الفانيليا
# المسك الفاتح
# المسك الداكن
# نجيل الهند الأرضي
# الأناناس
# اللافندر
# الحمضيات
# الياسمين
# السوسن
# الفلفل الوردي
# Tonka Bean
# Patchouli
# Cedar
# المسك
# طحلب البلوط
# العنبر
# الفانيليا
# الباتشولي
# الباتولا
# الياسمين المغربي
# الورد
# الأناناس
# البرجموت
# الكشمش الأسود
# التفاح
# الجلود
# العنبر
# الورد
# السوسن
# البرغموت
# الكشمش الأسود
# مكونات التوابل
# زنبق الوادي
# الياسمين
# روز
# الأرز
# الباتشولي
# الفانيليا
# الفلفل الأسود
# الليمون
# البرجموت
# إليمي
# البنفسج
# الزوفا
# المسك
# الارز
# الطحلب
# برغموت,ورد
# برقوق
# خمرة ,جلد
# خشب الصندل
# أخشاب الغاياك
# نجيل الهند
# أخشاب الأرز
# الأخشاب
# القرنفل
# اللبان
# الورد الدمشقي
# الكمثرى
# بوميلو
# الشامبانيا
# الفانيليا
# الورد
# الأخشاب الفرنسية
# البرجموت
# الياسمين
# ليمون
# زهر البرتقال
# شاي أخضر,بذور حب المسك
# هال
# شجرة الفلفل البيروفي
# خزامى سبايكنارد
# قرفة,بتشول
# خشب الصندل
# فانيليا
# نجيل الهند
# خشب الأرز الأبيض
# الشاي الأخضر
# الكشمش الأسود
# أخشاب الهلال
# الفلفل الأسود
# زهر البرتقال
# توت العرعر
# الورد
# الياسمين
# الفانيليا
# المسك الأبيض
# المسك
# العنبر
# التوابل
# عود ملكي
# عود السلطان
# المسك
# البرغموت
# الحبهان
# خشب الأرز
# خشب الغاياك
# نجيل الهند
# الراتنج
# أخشاب الورد
# المسك
# العنبر
# زهور البرتقال
# الزنبق
# الكزبرة
# البرجموت
# اللافندر
# الخوخ الناضج
# ورد التوت البري
# المسك العربي
# العود
# الطبيعي
# المسك
# أوراق الباتشولي
# خشب الغاياك
# خشب الساج
# زهر البرتقال
# اللافندر
# الهيل
# جوزة الطيب
# الجريب فروت
# النعناع
# تفاح جراني سميث
# البرغموت
# المسك
# الفانيليا
# الكرز
# الشيكولاتة
# الكرز
# الرم
# البرجموت
# الياسمين
# التوت البري
# الفانيليا
# توت العليق
# زهر البرتقال
# روز المطلق
# الفانيليا
# المسك
# البرجموت
# الورد الدمشقي
# أزهار الفاوانيا
# المسك الأبيض
# العنبر
# الباتشولي
# المسك
# مسك الروم
# الإيلنغ
# الياسمين
# الكمثرى
# الفلفل الوردي
# البرغموت
# الإيطالي
# وخلاصة
# زهر
# البرتقال
# والفلفل
# الأسود
# واللافندر
# والهيل
# والمريمية
# وتوت
# العرعر
# والسوسن
# والجلد
# ونجيل
# الهند
# والعود
# والبلوط
# الفانيليا
# الياسمين
# السوسن
# التين
# جوز الهند
# الأوركيد
# الزهور البيضاء
# الإيلنغ
# المسك
# الفانيليا
# أخشاب الأرز
# الكراميل
# الهيل
# الفلفل الحلو
# العنبر
# الأبيض
# بلسم بيرو
# الفانيليا
# الأخشاب
# زهور
# البرتقال
# الكحول
# عطر
# ماء
# هيدروكسي سيترونيلال
# سيترونيلول
#  ألفا-أيزو ميثيل أيونون
#  غيرانيول
# بولي إيثيلين جليكول ٤۰ زيت خروع مهدرج
# ليمونين
#  لينالول
#  إيجينول
# سيترال
# إيزوجينول
# فارنيسول
# الجلود
# القندس
# أخشاب العود
# المسك
# التفاح
# الفواكه الحمراء
# الزعفران
# الزنجبيل
# الجريب فروت
# الليمون
# البرجموت
# الأرز
# الورد
# العود
# الياسمين
# زهور البرتقال
# حبوب التونكا
# الفانيليا
# المسك
# الراتنجات
# الباتشولي
# البارغموت
# الهيل
# البنفسج
# أخشاب الأرز
# جوزة الطيب
# القرنفل
# العنبر
# المسك
# الباتشولي
# التونكا
# الفانيليا
# التفاح
# الهيل
# الورد
# الياسمن
# البنفسج
# خشب الصندل
# الباتشولي
# الفانيليا
# الباتشولي
# العنبر
# الجرجون
# التبغ
# حبوب التونكا
# اخشاب الأرز
# البخور
# البرتقال
# توت العليق
# الليتشي
# الزنجبيل
# الماندرين
# البرتقال
# الفلفل
# الياسمين
# العنبر
# المسك
# الياسمين
# ليمون حلو
# ليمون
# برتقال
# بنفسج
# كمون
# ريحان
# أكليل الجبل
# شمام,خزامى
# نرجش
# تيوليب
# بنفسج
# إيلانغ
# زهرة العسل
# زنبق,ميموزا
# مسك أبيض
# نجيل الهند
# أخشاب الصندل
# الفانيليا
# الباتشولي
# العنبر
# الياسمين
# الكرز الأسود
# العليق
# البرقوق
# السحلبية المزهرة ليلاً
# السوسن
# الفريزيا
# العنبر
# المسك
# فانيلا
# البرتقال
# الحمضيات
# الزهور
# الصمغ
# الشيح
# القرفة
# جوزة الطيب
# الرم السكري
# فاكهة النجمة
# مياه البحار
# الموز
# إبرة الراعي
# إندول
# فرانجيباني
# القرنفل
# الإيلنغ
# العنبر
# خشب الصندل
# الفانيليا
# المسك
# زهرة الخلود
# البرغموت
# القرنفل
# المانجو
# الباتشولي
# الورد
# البتشولي
# الفانيليا
# المسك
# الفلفل الوردي
# الفلفل الأسود
# الأرز
# اللوز
# القهوة
# الليمون
# البرغموتزهر البرتقال
# الورد
# مسك الروم
# الياسمينفول التونكا
# الكاكاو
# الفانيليا
# المسك
# العنبر
# خشب الكشمير
# الباتشولي
# القرفة
# الأرز
# حلوى البرالين
# خشب الصندل
# العسل
# القرفة
# الياسمين
# زهور البرتقال
# الورد
# العود
# العنبر
# المسك
# العنبر
# الفانيليا
# الورد
# القهوة
# الأزهار
# البرغموت
# مسك الروم الهندي
# الفانيليا
# العنبر
# العنبر
# المسك
# أخشاب الأرز
# الكراميل
# جذور السوسن
# البلسم
# الياسمين
# الليمون
# البرجموت
# الفواكه
# حبوب التونكا
# أخشاب الأرز
# الإيلنغ
# الياسمين
# البرجموت
# أخشاب
# الأرز
# الورد
# الجوري
# العنبر
# اليوزو
# حمضيات
# الفاكهة المائية
# زهر البرتقال
# شاي الياسمين
# زنبق الماء
# الباتشولي الأبيض
# خشب الأرز
# خشب الصندل
# الفانيليا
# أخشاب الصندل
# المسك
# العنبر الرمادي
# أخشاب الغاياك
# الجرجون
# كاشميران
# نارجاموثا
# زهور
# إليمي
# الفانيليا
# المسك
# أخشاب الأرز
# الخوخ
# زهور الأوركيد
# الماجنوليا
# الكمثرى
# البرجموت
# البطيخ
# مشمش
# خوخ,خزامى
# كاشميران
# سوسن,بتشول
# خشب العنبر
# طحلب الكريستال
# البلوط
# الباتشولي
# أخشاب أكيجالا
# زئبق
# الزنجبيل
# الأبيض
# البرجموت
# التوت المعجزة
# المسك
# الفانيليا
# حبوب التونكا
# البودر
# العنبر
# الياسمين
# الورد
# زهر البرتقال
# الماندرين
# يلنج يلانج
# الأغاف
# مسك الروم
# الفانيليا
# المسك الابيض
# خشب الأرز
# خشب الصندل
# المسك
# العنبر
# الأخشاب
# العود
# الياسمين
# الشاي
# الباتشولي
# الزعفران
# البرجموت
# الجريب فروت الوردي
# أخشاب الصندل
# العنبر
# حبوب التونكا
# المسك
# نجيل الهند
# البنفسج
# السوسن
# النرجس
# جذور السوسن
# الياسمين
# زنبق الوادي
# الورد
# اليوسفي
# الخوخ
# البرجموت
# الفراولة
# أخشاب الأرز
# الباتشولي
# نجيل الهند
# اللافندر
# اليانسون
# حجر الدم
# اليوسفي
# الفلفل الأسود
# الفانيليا
# أخشاب الأرز
# المسك الأبيض
# حجر الدم
# اللبان
# الورد
# جوزة الطيب
# زهور البرتقال
# زهور الخليج
# الحلوى
# الفانيليا
# زهور البرتقال
# العنبر
# الكمثرى
# الزنجبيل
# روز
# خوخ
# عنبر
# مسك
# باتشولي
# خشب الصندل
# الجريب فروت الأندلسي
# الحمضيات
# الليمون الصقيلي
# اللوز
# الفلفل الوردي
# البرغموت
# البرقوق
# القرفة
# الهليوتروب
# التبغ
# الجلود
# الباتشولي
# خشب الأرز
# الرذاذ المائي
# الليمون
# أخشاب الأرز
# المسك الأبيض
# الفانيليا
# الورد
# الفانيليا
# البرتقال
# الخوخ
# الماندرين
# الكمثرى
# الكرز
# البرجموت
# زنبق الوادي
# الفاونيا
# ياسمين سمباك
# الأخشاب
# المسك الأبيض
# نجيل الهند
# الباتشولي
# أليوسفي الأخضر
# زهر البرتقال
# مسك الروم
# زهر البرتقال
# المارشيملو
# خشب الصندل
# الهيل
# الماندرين
# اللوتس
# الزنجبيل
# الفلفل الوردي
# الشيح
# البنفسج
# الكزبرة
# المسك
# الباتشولي
# العنبر
# الفانيليا
# حبوب التونكا
# الزهور البيضاء
# التوابل البيضاء
# أخشاب
# الصندل
# الكستناء
# ميرابيل
# البنزين
# أخشاب الأرز
# الباتولا
# البخور
# الكسبرة
# الفلفل
# الليمون
# اليوزو
# زهور البرتقال
# الكمثرى
# هيليوتروب
# زهور الباشون
# خشب الصندل
# المسك
# العنبر
# خشب الأرز
# التبغ
# القهوة
# الزبيب
# الزهور البرية
# الرمان
# الزعفران
# العود
# الأخشاب
# الكمون
# البنزوين
# الباتشولي
# البخور
# ورق الباردي
# الورد
# الفانيليا
# البرالين
# الليتشي
# الزهور السوداء
# أخشاب الصندل
# المسك
# العنبر
# الياسمين
# الورد
# الفريزيا
# البرجموت
# الليمون
# اليوسفي
# عصير الكمثرى
# العود
# المدخن
# الكمثرى
# الشيكولاتة الداكنة
# الورد الدمشقي
# الياسمين المغربي
# الفانيليا
# الدرنة
# الأوسمانثوس
# خشب الصندل الأسترالي
# العنبر
# الفانيليا
# البرتقال
# الخوخ
# الورد المغربي
# خشب الصندل
# الزعفران
# العنبر
# الفانيليا
# المسك الأبيض
# توت العليق
# التفاح
# أخشاب الأرز
# الجريس
# ليمون سيسيليا
# الورد الأبيض
# نبات البامبو
# الياسمين
# العنبر
# المسك
# أخشاب الأرز
# جريب فروت
# برتقال ذهبي
# حمضيات
# زهور بيضاء
# مسك
# بهارات
# ليمون كالاباري
# حلوى تركية
# روز
# خشب الأرز
# فانيليا مكثفة
# مسك أبيض
# الليمون
# الحمضيات
# البرسيم الآيرلندي
# الجلود
# أوراق الليمون
# البرسيم
# الياسمين
# الفريزيا
# البنفسج
# ميموزا
# السوسن
# البرجموت
# الورد
# زنبق الوادري
# جلبانوم
# السوسن
# مسك الروم
# الكزبرة
# البابونج
# النرجس
# إبرة الراعي
# زهر البرتقال
# أخشاب الورد البرازيلية
# الياسمين
# خشب الأرز
# الفانيليا
# المسك
# العنبر
# خشب الصندل
# البرجموت
# الأوراق الخضراء
# زنبق الوادي
# زهور الخوخ
# زهور البرتقال
# زهور الكابوسين
# الورد
# المسك
# العود الماليزي
# العود الهندي
# العود الفيتنامي
# المسك
# أمبروكسان
# أخشاب الصندل
# الورد
# زهور البرتقال
# اليوسفي
# الفواكه
# الورد
# الأخشاب النقية
# العنبر
# المسك
# الفاونيا
# الفريزيا
# الفواكه
# الكمثرى
# الباتشولي
# العنبر
# العود
# الورد
# المسك
# الزعفران
# رحيق التوت
# لبان
# باتشولي
# خشب الصندل
# عنبر
# عود
# الدخان
# أخشاب الصندل
# الأخشاب
# المسك
# بخور مريم
# الورد الدمشقي
# الماغنوليا
# الفاونيا الوردية
# الفراولة
# البطيخ
# البرجموت
# الليتشي
# البرتقال
# مزيج زهري
# الخوخ
# الياسمين
# نفحات خشبية
# المسك الأبيض
# يوزو
# البارغموت
# التفاح الأحمر
# المانغوليا
# الورد
# مسك الروم
# الأوسمانثوس
# النيورولي
# أوراق التين
# الكزبرة
# براعم البرتقال
# التيوليب
# دهن العنبر
# الجاوي
# المسك
# كحول دينات
# عطر
# أكوا
# ماء
# ليمونين
# هيدروكسي سيترونيلال
# لينالول
# سيترونيلول
# يوجينول
# جيرانيول
# سيترال
# ميثيل 2-أوكتينوات
# توكوفيرول
# الكزبرة
# كاسيا
# البرغموت
# أوراق البنفسج
# الفاوانيا
# الياسمين
# الغاردينيا
# الورد
# السوسن
# خشب الأرز المغربي
# المسك الأبيض
# زهر البرتقال
# الورد
# الياسمين
# الفانيليا
# خشب السنديان
# الباتشولي
# العنبر
# أوراق الغار
# زهور الياسمين
# الجريب فروت
# النسمات البحرية
# عود
# اللبان
# المسك
# الورد
# أوسمانثوس
# باتشولي
# الكشمش الأسود
# المشمش
# فريزيا
# أخشاب الأرز
# المسك
# زنبق الوادي
# الورد
# صريمة الجدي
# الفاوانيا
# الفلفل الوردي
# الكشمش الأسود
# الفراولة
# الكمثرى
# برغموت
# ليمون
# يوسفى
# فلفل وردي
# زهر البرتقال
# الحبوب الصغيرة
# الياسمين
# أعشاب خضراء
# مسك
# بلوميريا
# يلانغ
# مسك الروم
# زهرة البرتقال
# فل
# باتشولي
# فانيليا
# نجيل الهند
# زهرة السوسن
# التبغ
# أخشاب الصندل
# أخشاب الأرز الفرجيني
# الجلود
# المسك
# أوسمانثوس
# الإيلنغ
# نجيل الهند
# طحلب البلوط
# الباتشولي
# روزماري
# نعناع
# ​​بابريكا
# ياسمين
# الجريب فروت
# اليوسفي
# الأخشاب
# المر
# البخور
# المخمل
# العود
# الجلود
# الزعفران
# الفلفل الأسود
# زيت نجيل الهند
# الباتشولي
# الكشميران
# المسك
# الأمبروكسان
# الجلد
# السوسن
# العود
# البرغموت
# الجزر
# اللافندر
# أوراق خضراء
# زهرة الجاردينيا
# الياسمين
# خشب الصندل
# الباتشولي
# حبوب التونكا
# كاشميران
# Bergamot
# Raspberry
# Blackberry
# Pink Pepper
# Datura
# Orange Blossom
# Peony
# Jasmine Sambac
# Patchouli
# Cashmeran
# Ambroxan
# White Musk
# الكحول
# عطر
# أكوا (ماء)
# ليمونين
# لينالول
# بوتيل ميثوكسيديبنزويل ميثان
# سيترونيلول
# كومارين
# جيرانيول
# سيترال
# بنتاريثرتييل تترا دي تي بيوتيل هيدروكسي هيدروكينامات
# فارنيسول
# إيزويوجينول
# الجلود
# المر
# الزعفران
# الزعتر المجفف
# التفاح
# خشب الصندل
# شجرة الزيتون
# الفانيليا
# مسك مللو
# البرجموت
# الكمثرى
# قطرات الندى
# الورد
# السوسن
# هيليوتروب
# المسك
# الأبيض
# كاشميران
# الماندرين
# العنبر
# المسك
# العود
# الفاونيا
# الورد
# الجاوي الأحمر
# الزعفران
# السوسن
# التوت الأحمر
# الجاوي
# التبغ
# الفلفل الأحمر
# القرفة
# الزعفران
# الفلفل الوردي
# الفواكه الحمراء
# برتقال ماندرين
# جريب فروت
# خوخ
# توفي
# ورد دمشقي
# بنفسجي
# ورد
# باتشولي
# مسك
# طحلب
# Sugar
# Musk
# Violet
# Freesia
# Blackberry
# Boysenberry
# Iris
# Bergamot
# Mandarin
# Lily-of-the-Valley
# Woody Notes
# الأخشاب الثمينة
# الباتشولي
# طحالب البلوط
# العنبر
# اللابدانوم
# الكراميل
# العنبر
# البرجموت
# التوابل
# بتلات الورد
# الصندل
# العود
# النوتات الخضراء
# البرتقال
# الفلفل الوردي
# الكشمش الأسود
# التفاح
# البرجموت
# الاناناس
# زهور البرتقال
# الهيديون
# بخور مريم
# الياسمين
# الورد
# توت العرعر
# الشمام
# الباتشولي
# الباتولا
# خشب الأرز
# المسك
# الجلد
# طحلب البلوط
# الفانيليا
# أمبروكسان
# العنبر
# الصندل
# الباتشولي
# البخور
# الفانيليا
# اللوتس
# الأأزهار
# الأوركيد
# التوابل
# الإيلنغ
# الياسمين
# الماندرين
# الحمضيات
# البرجموت
# الجاردينيا السوداء
# القرفة
# الأرز
# خشب الصندل
# مسك مالو
# أوراق البنفسج
# جذور السوسن
# افانيليا
# أخشاب الكاشمير
# المسك
# زنبق الوادي
# الياسمين
# إبرة الراعي
# الإيلنغ
# حجر الدم
# البنفسج
# الخوخ
# توت العليق
# زهور مايو
# البرجموت
# أخشاب الصندل
# حبوب التونكا
# المريمية
# اللافندر
# خشب
# عود
# تراد
# زنجبيل
# الحبهان
# الفلفل
# براعم البرتقال
# الفاوانيا
# الجاردينيا
# جوز الهند
# خشب الصندل
# المسك
# العنبر
# الكمثرى
# الجريب فروت الوردي
# الورد الياباني
# الياسمين
# المسك
# الخشب
# أخشاب الصندل
# العود
# الجلود
# الباتشولي
# البخور
# العنبر
# اللبان
# المر
# البرجموت
# أوريجانو
# زيت التوت الحلو
# أمبروكسان
# حبوب التونكا
# التمر
# زهور البرتقال
# البرجموت
# الماندرين
# النيرولي
# دينات الكحول (كحول إس دي 39-سي)
# عطر
# أكوا (ماء)
# ألفا إيزوميثيل أيونون
# بنزيل ساليسيلات
# كحول سيناميل
# سيترال
# سيترونيلول
# كومارين
# ليمونين
# لينالول
# الأرز
# العنبر
# المسك
# الفانيليا
# الياسمين
# زهور البرتقال
# اللافندر
# الحبوب الدقيقة
# الكشمش الأسود
# اللافندر
# الماندرين
# العود
# العنبر
# البخور
# الزهور
# المسك
# البلغاري
# زهور الزعفران
# زهور البرتقال
# الزعفران
# البازلاء الحلوة
# البرغموت
# برتقال
# جريب فروت
# المسك
# فريزيا
# السفرجل
# الخوخ
# جاردينيا
# الباتشولي
# ألوردة الدمشقية
# روز
# جلد
# المسك
# الأزهار
# السكر
# الفواكه المجففة
# اللبن
# ماسيوا
# أخشاب الصندل
# توت جوجي
# الجريب فروت
# الخوخ
# الفاونيا
# المسك
# الأخشاب البيضاء
# العود
# البارد
# العنبر
# الأزرق
# المسك
# الياسمين
# الورد
# الإيلنغ الإيلنغ
# التونكا
# الياسمين
# الورد
# البودرة الحلوة
# الهليوتروب
# المسك
# العنبر
# طحلب السنديان
# حبوب التونكا
# الفانيليا
# الياسمين
# نجيل الهند
# الكرز
# الورد
# اللوز المر
# الفلفل الوردي الحامض
# الأرز
# العود
# خشب الصندل
# المسك
# الياسمين
# المسك الأبيض
# الورد
# الفانيليا
# ,مريمية
# خزامى,خشب الكشمير
# فانيليا
# بتشول
# المسك
# الفانيليا
# أخشاب الصندل
# السوسن
# الياسمين
# الباتشولي
# الزهور البيضاء
# الصنوبر
# الورد
# الكومارين
# البرجموت
# البرقوق
# الزعفران
# زهرة السوسن
# الورد البغاري
# الفل
# جذور السوسن
# خشب بردي
# نجيل الهند
# عنبر
# الخوخ
# البرغموت
# الأوسمانثوس
# الورد
# زهرة السوسن
# مسك الروم
# النرجس
# العنبر
# الأرز
# المسك
# أوراق البنفسج
# الليمون الأخضر
# الليمون
# الورد
# ياسمين سمباك
# خشب الأرز
# أخشاب الكاشمير
# المسك
# دينات الكحول (كحول SD 39-C)
# عطر (عطر)
# أكوا (ماء)
# جيرانيول
# سيترونيلول
# ليمونين
# لينالول
# سيترال
# الكراميل
# الفانيليا
# المسك
# السوسن
# البنفسج
# الباتشولي
# الياسمين
# البرجموت
# الفلفل الأسود
# الكشمش الأسود
# البرتقال
# مسك الروم
# الياسمين
# العود
# الجاوي
# خشب الغاياك
# برجموت كالابريا
# الباتشولي
# العنبر
# الورد
# العود
# العنبر
# المسك
# الفانيليا
# القرفة
# الزعتر
# التفاح
# الزنجبيل
# رذاذ الماء
# الأرطماسيا
# الفيرموث
# الليمون
# البخور
# البابونج والمشمش والأرز والعنبر
# جلد
# مسك
# فانيليا
# العنبر
# الخشب
# مسك
# الروم
# انجليكا
# النوتات الشمسية
# شجر الصنوبر
# الحمضيات
# الورد
# الورد الأبيض
# الياسمين
# الخوخ
# الألدهيدات
# البرجموت
# البرتقال الأحمر
# البرغموت
# الماندرين
# الخوخ
# الكشمش الأسود
# ديوبيري
# ورد
# النيرولي
# الغرنوقي
# هيل
# الفلفل الوردي
# الفلفل الأسود
# فانيلا
# كاكاو
# اللبان البدوي
# العنبر
# المسك
# باتشولي
# خشب الصندل
# مالتول
# البنزوين
# الباتشولي
# البخور
# ورق الباردي
# الورد
# الفانيليا
# البرالين
# الليتشي
# الزهور السوداء
# المسك
# الباتشولي
# أخشاب الأرز
# حبوب التونكا
# الفانيليا
# نجيل الهند
# طحلب البلوط
# القرنفل الملون
# الياسمين
# إبرة الراعي
# زهور القرنفل
# الكسبرة
# إكليل الجبل
# اليانسون
# البرجموت
# ليمون أمالفي
# اللافندر
# شمع
# العسل
# الورد البلغاري
# أوراق البنفسج
# الليمون
# النعناع
# المسك
# الأبيض
# اللافندر
# زهور البرتقال
# لويزة الليمون
# السيترون
# البرجموت
# الزنجبيل
# الزنجبيل
# البهارات
# الفلفل الأحمر
# الفلفل الأسود
# القرنفل
# الهيل
# الزعفران
# جوزة الطيب
# الجلد
# المسك
# البرغموت الإيطالي
# المشمش الذهبي
# الريحَان
# رائحة حلوى الشربات المثلج
# السحلبية
# الفريزيا
# ياسمين سامباك
# نفحات أخشاب الخريف
# الكشمير
# المسك
# خلاصة الفيتيفر
# المسك
# الياسمين
# البودرة
# العسل
# العنبر
# الفانيليا
# المسك
# الباتشولي
# جذور السوسن
# الأناناس
# الياسمين
# نسيم البحر
# الحمضيات
# الفلفل الوردي
# الصفير
# أخشاب الصندل
# آيزو آي سوبر
# أخشاب الأرز
# المسك الأبيض
# البنفسج
# نجيل الهند
# الورد
# هيديوني
# النيرولي
# السوسن
# البرجموت
# الجلبانوم
# الفلفل الوردي
# العرعر
# المريمية
# الحلوى
# الرفيق
# الأعشاب
# السوسن
# العنبر
# البتولا
# الجلود
# حبوب التونكا
# زهر البرتقال
# مسك الروم
# العنبر
# اللابدانوم
# ورد
# ياسمين
# عود
# الزهور البيضاء
# الإيلنغ
# البودرة
# اللوز
# العنبر
# حبوب التونكا
# المسك
# الباتشولي
# الكاكاو
# الورد البلغاري
# السوسن
# الجلود
# الفواكه
# الباتشولي
# أخشاب الصندل
# المسك
# العنبر
# أخشاب الأرز
# الورد
# الياسمين
# البنفسج
# البرجموت
# الزنجبيل
# رذاذ البحر
# الجلود
# الكراميل
# الأخشاب
# الليتشي
# الورد السوداء
# العود
# البرتقال
# الكمثرى
# المسك
# الورد
# الفواكه
# اللبان
# الأخشاب
# العود
# الفانيليا
# خشب الصندل
# العود
# أخشاب الكشمير
# الورد
# الفانيليا
# العنبر
# المسك
# الياسمين
# الفانيلا
# الريحان
# الورد الأبيض
# الجلود
# المسك
# العود
# العنبر الأبيض
# إكليل الجبل
# البرجموت الصقيلي
# الفلفل الوردي
# الفانيليا
# المسك
# جوزة الطيب
# الأخشاب
# العنبر
# الزنجبيل
# المسك الأبيض
# الفانيليا
# الحلوى
# زهور البرتقال
# زهور الزنجبيل
# الياسمين
# الماندرين البرتقالي
# الزنجبيل
# خشب الأبنوس
# قهوة
# برتقال دم الزغلول
# كحول
# عطر
# ماء
# بيوتيلفينل مثييل بروبيانول
# ليمونين
# أفوبينزون
# إيثيل هيكسيل ميثوكسينامات
# سيترونيلول
# بوتيل هيدروكسي تولوين
# جيرانيول
# لينالول
# سترال
# ألفا-ايزوميثيل ايونون
# ميثيل 2-أوكتينوات
# كحول بنزيلي
# أوجينول
# بينزوات البينزيل
# فارنيسول
# الليمون
# المسك الأبيض
# الفانيليا
# الهيل
# العرعر
# الوسكي
# الورد
# المسك
# العنبر
# خشب الأرز
# الشاي
# العنبر
# المسك
# الباتشولي
# أخشاب الصندل
# أخشاب الأرز
# اللابدانوم
# نجيل الهند
# العود
# الفانيليا
# الجاردينيا
# الورد
# البنفسج
# اللافندر
# إبرة الراعي
# البرجموت
# التوت الطازج
# لبرغموت
# عشبة الراوند
# زهرة ايار
# الفيوليت
# توت العليق
# المسك
# الكشمير
# ...
# عطر
# أكوا (ماء)
# ليمونين
# بنزيل ساليسيلات
# كحول بنزيل
# بنزيل بنزوات
# قرفة
# كحول سيناميل
# سيترال
# سيترونيلول
# كومارين
# يوجينول
# فارنيسول
# جيرانيول
# هيدروكسيترونيلال
# إيزويوجينول
# لينالول
# الكشمش الأسود
# الفلفل الوردي
# البرغموت
# ياسمين سامباك
# الياسمين
# شاى الياسمين
# فانيليا بوربون
# أخشاب الكشمير
# أخشاب الغاياك
# اللابدانوم
# البرجموت
# البرتقال
# زهور البرتقال
# الحبوب الدقيقة
# النيرولي
# ستيراكس
# المسك
# العنبر
# حبوب التونكا
# العود
# البنزوين
# خشب الورد البرازيلي
# طحلب البلوط
# اللابدانوم
# البخور
# أخشاب الغاياك
# إليمي
# نجيل الهند
# العود اللاوسي
# الباتشولي
# أخشاب الغاياك
# أميريس
# أخشاب الصندل
# جذور السوسن
# أوراق الغار
# نبات الطرخون
# زهور البرتقال
# زهرة القريضة
# زهور القرنفل
# الإيلنغ
# الورد
# الكشمش الأسود
# أوراق البنفسج
# المسك
# بخور مريم
# الألدهيدات
# الأخشاب
# المسك
# الورد
# البرجموت
# العنبر
# الجلود
# العود
# المسك
# العنبر
# حبوب التونكا
# العنبر
# الفانيليا
# الجوز
# الزعفران
# القرفة
# القرنفل
# فلفل أبيض
# برغموت
# ليتشي,جوزة الطيب
# بطيخ
# نعناع
# خزامى,مسك أبيض
# عنبر
# خشب الأرز
# بوربون نجيل الهند
# الميموزا
# اليوسفي
# البرتقال
# البرجموت من كالابريا
# الإيمورتيل
# الفل
# الورد التركي
# الباتشولي
# نجيل الهند
# خشب الصندل
# العود
# المسك
# الورد
# البنفسج
# البرجموت
# الورد
# الفواكه
# الفواكه الاستوائية
# المسك
# زهرة البرتقال
# الباتشولي
# العنبر
# الفواكة الإستوائية
# ستيراكس
# جاوي سيام
# حبوب التونكا
# بذور الفانيليا
# اللافندر
# الزعتر
# أخشاب الأرز
# أخشاب الصندل
# الجلود
# أوراق التين
# الفلفل الأسود
# الزنجبيل
# البخور
# التين
# البرغموت
# الفلفل الوردي
# الياسمين
# الباتشولي
# الجلد
# الجلود
# العنبر
# المسك
# الأخشاب
# العنبر
# أخشاب الصندل
# الفانيليا
# الفاونيا
# المارشميللو
# الكشمش الأسود
# البرقوق
# الماندرين
# اللوز الأخضر
# الماغنوليا
# مسك الروم الدرني
# ورد
# رقيب الشمس
# حلوى مونت بلانك
# باتشولي
# خشب الصندل
# الكحول
# دينات 80٪ فول
# أكوا (ماء)
# عطر (عطور)
# سيترال
# سيترونيلول
# د-ليمونين
# فارنسول
# جيرانيول
# هيدروكسي أيزو إكسيل-3 سيكلوهكسين كربوكسالديهايد
# لينالول
# حبوب التونكا
# اللابدانوم
# الزعفران
# البرجموت
# المسك
# اللافندر
# العنبر
# الجلود
# التوابل
# أخشاب الأرز
# المسك
# أخشاب الصندل
# الياسمين
# الزنبق المائي
# الخوخ
# البرجموت
# الأناناس
# نبات نجيل الهند
# الباتشولي
# العنبر
# الفانيلا
# اللافندر
# النعناع
# حبوب التونكا
# نبتة الاوكالبتوس
# الهيل
# البرغموت
# الزنجبيل
# البخور الصومالي
# الأمبريت
# الورد التركي
# الزعرور
# الفريزيا
# القرفة
# الزعفران
# خشب الصندل
# المسك
# العنبر
# الفانيليا
# التونكا
# الفانيليا
# المسك
# السوسن
# البنفسج
# كحول
# عطر
# أكوا (ماء)
# ليمونين
# هيدروكسي سيترونيلال
# سيترونليلول
# بنزيل سينامال
# بنزيل ميثوكسيسينامات
# لينالول
# بوتيل ميثوكسيديبنزويل ميثان
# بوتيلين جليكول ديكابريلات / ديكابرات
# يوجينول
# كحول سيترال
# البنفسج
# الباتشولي
# السويدي
# داليا
# اللافندر
# الياسمين
# النيرولي
# الماندرين الإيطالي
# الطماطم
# الزهور
# الباتشولي
# الكشمش الأسود
# البرجموت
# زهر البرتقال
# الشاي الأخضر
# الباتشولي
# خشب الصندل
# المسك
# اليوسفي
# البرغموت
# عطر البرتقال الحلو
# اللافندر
# الخزامى
# المريمية
# الفلفل
# التبغ
# الأرز
# التونكا
# بتيت جرين
# أعشاب طازجة
# سوسن
# خشب الصندل
# مسك,بيرش
# إيفرينا خوخية
# حبهان,طحلب
# خشب الورد
# نجيب الهند
# زيت الورد
# الفاوانيا
# اليوسفي
# الوردة
# العنبر
# العود
# الباتشولي
# الأوركيد
# الياسمين
# الجلود
# الحمضيات
# الزعفران
# كحول دينات
# عطر (عطور)
# أكوا (ماء)
# لينالول
# بوتيل ميثوكسي ديبينزويل ميثان
# ليمونين
# جيرانيول
# يوجينول
# كحول
# تريس (تتيراميثيل هيدروكسي بيبريدينول) ساليسيلات البنزيل
# CI 19140 (أصفر 5)
# CI 14700 (RED 4)
# CI 60730 (EXT VIOLET 2)
# فانيليا مدغشقر
# المسك الأبيض
# الورد الدمشقي
# زهور مايو
# الكشمش الأسود
# برجموت كالابريا
# الأخشاب
# العود
# الفانيليا
# التبغ
# العربي
# أزهار ساكورا
# مسك الروم
# غاردينيا
# الفانيليا
# أوراق
# الباتشولي
# الأندونيسي
# الخوخ
# الأحمر
# الفانيليا
# الأخشاب
# أحجار العنبر
# حبوب التونكا
# أخشاب الغاياك
# الجاوي
# الفلفل الأسود
# الجلود
# الفانيليا
# البرالين
# خشب الصندل
# الأرز
# المسك
# حلوى التفاح
# الياسمين
# الفاوانيا
# الفواكه
# الليمون
# الخوخ
# الزعفران
# الجريب فروت
# الورد
# العود
# المريمية
# العنبر
# روائح خشبية
# اللبدانوم
# حبوب التونكا
# رائحة الألدهيدات
# البرتقال
# الفاكهة وعبير البرغموت
# زهرة القرنفل
# خشب الصندل
# الباتشولي
# القرفة
# جذور السوسن
# خشب الأرز والورد
# العسل
# حبوب التونكا
# العنبر
# المسك
# الجاوي
# طحلب السنديان - السنديان حزازيات والفانيلا
# الفانيليا
# السويدي
# المسك الأبيض
# السوسن
# الفاونيا
# الورد الدمشقي
# البرجموت
# الجريب فروت
# الخوخ الأبيض
# البرتقال
# البرجموت
# الماندرين
# زهور البرتقال
# الإيلنغ
# الورد
# الياسمين
# الميوزا
# الباتشولي
# الفانيليا
# المسك
# نجيل الهند
# اللافندر
# الجيرانيوم
# البرتقال
# الباتشولي
# قرفة سيلون
# الورد
# خشب الصندل
# العنبر
# الفانيليا
# البرتقال
# الزعفران
# زنبق الوادي
# أوراق البنفسج
# الكراميل
# العنبر
# المسك
# المسك
# العنبر
# الفانيليا
# البنزين
# حبوب التونكا
# الأخشاب البيضاء
# الباتشولي
# البنفسج
# المانغوليا
# الورد المغربي
# جذور السوسن
# الورد البلغاري
# توت العليق
# إبرة الراعي
# البرجموت
# الباتشولي
# العنبر
# الجلود
# البنفسج
# جذور السوسن
# الورد الأحمر
# الزعفران
# الفلفل الأسود
# توت العليق
# القرفة
# القرنفل
# رذاذ البحر
# الياسمين
# الحمضيات
# البرتقال المر
# زهر البرتقال
# الياسمين
# الورد
# الباتشولي
# السوسن
# البخور
# اللبان
# الجاوي
# الأخشاب
# المسك
# فانيليا تاهيتي
# الشيكولاته البيضاء
# البرغموت
# الفلفل الوردي
# الزعفران الأبيض
# عود
# جلد مخملي
# أخشاب الأرز
# أخشاب الصندل
# الثوم
# المسك
# نجيل الهند
# الياسمين
# الورد
# الزنبق
# زهور البرتقال
# نجيل الهند
# الماندرين
# البرجموت
# الليمون
# الألدهيدات
# الكشمش الأسود
# الماندرين
# التوت
# الخوخ
# البرغموت
# قرنفل
# مسك الروم
# الأوركيد
# السوسن
# الياسمين
# هياسينث
# الروز
# الإيلنغ
# زنبق الوادي
# النرجس
# العسل
# خشب الصندل
# حبوب التونكا
# العنبر
# المسك
# الزباد
# الفانيليا
# إيفرنيا خوخية
# نجيل الهند
# العنبر
# المسك
# الخشب
# أوركيد البرية
# زهر البرتقال
# كليمنتين
# نكتارين
# كشمش أسود
# الباتشولي
# المسك
# العنبر
# جوز الهند
# الفانيليا
# أخشاب الصندل
# الياسمين
# الورد
# توت العليق
# الماندرين
# البرتقال
# التفاح
# الكمثرى
# البرغموت
# سيدرات
# الفلفل الوردي والقرنفل والهيل وجوزة الطيب واللافندر والروزماري
# البتشولي وخشب الصندل والمسك
# الفانيليا
# حجر الدم
# المسك
# الكرز
# البنفسج
# الورد
# الأناناس
# الألدهيدات
# توت العليق
# فرمون
# العنبر
# حبوب الفلفل الأسود
# برغموت
# جوزة الطيب,غاردينيا
# مسك الروم
# ياسمين,مسك
# خشب الأرز
# خشب الصندل
# روم
# البرغموت
# قهوة
# الجلد;
# الباتشولي
# و
# أشجار
# السرو;
# الأخشاب
# و
# نجيل
# الهند
# المسك
# الورد الجوري
# الجاردينيا
# الكمثرى
# التوت
# الليتشي
# باتشولي
# الفانيليا
# Ginger
# cardamom
# pepper
# orange buds
# peony
# gardenia
# coconut
# sandalwood
# musk
# amber
# اللبان
# العماني
# البودرة
# اللافندر
# التوت الأحمر
# البرتقال
# أوسمانثوس
# المسك
# العنبر
# الكشمير
# الطحلب الأبيض
# العنب
# الجلود
# الباتشولي
# الهيل
# الياسمين
# اللافندر
# فانيليا مدغشقر
# العنبر
# نجيل الهند
# أخشاب الأرز
# أخشاب الكشمير
# العنبر
# البنزوين
# الجلود
# القرنفل
# القرفة
# الفلفل الوردي
# الجريب فروت
# الجريب
# فروت
# وفاكهة
# العليق
# والفلفل
# الوردي
# والياسمين
# والفاوانيا
# والأرز
# والعنبر
# اللابدانوم
# الباتشولي
# العود
# الفلفل الوردي
# القرفة
# القرنفل
# البرجموت
# الورد
# توت العليق
# المسك
# البرتقال
# زهور البرتقال
# أوسمانثوس
# برجموت
# كالابريا
# المسك
# حلوى الماكرون
# الورد الزهري
# جوز الهند
# الكمثرى
# توت العليق
# المسك
# الأرز الأطلسي
# أخشاب الغاياك
# نجيل الهند
# الورد البلغاري
# الهيل الجواتيمالي
# الإيلنغ
# قرفة سيلان
# الجلود
# العنبر
# جوزة الطيب
# برجموت كالابريا
# الجريب فروت الوردي
# ليمون أمالفي
# أوراق الليمون
# رمان
# لوتس بلوسوم
# بلاك أوركيد
# عنبر
# خشب
# الباتشولي
# البنزوين
# البخور
# بلسم بيرو
# أبوبوناكس
# العنبر
# الزعتر
# البرغموت
# إبرة الراعي
# المريمية
# وردة البرتقال
# يلانغ يلانغ
# الباتشولي
# جاردينيا,ياسمين
# زنبق
# بتشول,صنوبر
# جلد
# مسك
# فانيلا
# الكراميل المملح
# السكر البني
# أخشاب الأرز
# الياسمين
# أوراق الغار
# الأعشاب البحرية
# الليمون الطازج
# ملح البحر
# الفلفل الوردي
# زهرة الفاونيا
# الخوخ
# الأوراق الخضراء
# فريزيا
# البرقوق
# المسك
# الياسمين
# الزنبق
# زنبق الوادي
# يلنج يلانج
# الحشائش الخضراء
# الورد
# القهوة
# الفانيليا
# حبوب التونكا
# خشب الصندل
# الكزبرة
# خشب الأرز
# البخور
# العنبر
# الباتشولي
# طحلب البلوط
# الأخشاب
# زهور البرتقال
# الياسمين
# الهيل
# الماندرين
# البرجموت
# جوزة الطيب
# باتشولي
# سوسن
# ورد بنفسجي
# الجريب فروت
# الكشمش الأسود
# أوراق البنفسج
# الشاي الأبيض
# الورد
# التونكا
# العنبر
# المسك الأبيض
# أخشاب الأرز
# الطحالب
# أخشاب الكاشمير
# الياسمين
# الورد الدمشقي
# الفاونيا
# الفلفل الوردي
# الليتشي الوردي
# الجريب فروت
# المسك الأسود
# المسك الرمادي
# المسك
# أخشاب الأرز
# العنبر
# المسك
# الأبيض
# الأخشاب البيضاء
# العنبر
# المس
# زهر العسل
# الورد
# البنفسج
# البرغموت
# الراوند
# التوت
# الفلفل الوردي
# الفانيليا
# السكر
# المسك الأبيض
# أخشاب الأرز
# الورد
# السكر
# الليمون
# الماء
# المسك
# العنبر
# الكشمير
# ليتشي
# ورق اللوتس
# يوسفي
# برغموت,زهرة الغرنوقي
# براعم اللوز
# ورد,مسك
# جوز الطيب
# فانيلا
# زهور الجبل
# القطن
# الجلود
# نجيل الهند
# أخشاب الأرز
# الباتشولي
# الروم
# ياسمين السامباك
# الدفانا
# فلفل سيشوان
# البرجموت
# توت أسود
# زنجبيل
# زهر برتقال
# فلفل
# آذريون
# كشمش أسود
# باتشولي
# ياسمين
# ورد
# نرجس
# جلود
# عنبر
# مسك
# بخور
# زيت الورد التركي
# الأوزون
# ملح البحر
# البرالين
# زيت الباتشولي
# العنبر المركز
# الفانيليا
# المسك
# العنبر الأبيض
# العود
# أخشاب الأرز
# بلسم جارجان
# أخشاب الصندل
# الزعفران
# جوزة الطيب
# الزنجبيل
# السوسن
# أخشاب الصندل
# المسك الأبيض
# الهيل
# زنبق الوادي
# الياسمين
# الفلفل الأخضر
# زهر البرتقال المر
# النيرولي
# أوراق الشاي
# الزعتر
# إكليل الجبل
# اللافندر
# المريمية
# الجير
# الماندرين الأخضر
# برجموت كالابريا
# البن المحمص
# الهيل
# الزعفران
# اللوتس
# مسك الروم
# الورد
# الفلفل
# عرق السوس
# الزنبق
# المسك
# السوسن
# الليمون
# الحبهان
# الكزبرة
# السرو
# الورد البلغاري
# إبرة الراعي
# الأرطماسيا
# الروم
# البخور
# العود
# المسك
# الباتشولي
# الليمون
# الياسمين
# الزعفران
# الهيل
# الورد
# الباتشولي
# خشب الأرز
# الفانيليا
# المسك
# اللبان
# خشب العود
# الهيل
# خشب الغاياك
# الفانيلا
# الزعفران
# زيت السيبريول
# ناجارموثا
# المشمش
# الطحالب
# المسك
# الفانيليا
# التوت
# أخشاب الصندل
# الياسمين
# اللافندر
# الإيلنغ
# الماندرين
# البرتقال
# الليمون
# أخشاب السدر
# نجيل الهند
# المريمية
# إبرة الراعي
# الورد
# الهيل
# الجريب فروت
# الزنجبيل
# ليمون
# زنجبيل
# نعناع
# الهال
# برتقال الماندرين
# بلسم الكوبيبا
# خشب الصندل
# سيدار
# المسك
# نجيل الهند
# خشب نوتيس
# فرجينيا سيدا
# العنبر
# النبيذ الأحمر
# الماروزا
# الدافان
# الليمون
# الجريب فروت
# أخشاب الأرز
# المسك
# أمبروكسان
# الخوخ
# النيرولي
# الكالوني
# التوت
# رذاذ البحر
# الماندرين
# الليمون
# البرجموت
# أخشاب الأرز
# الخوخ
# الباتشولي
# المسك
# الفانيليا
# زنبق الوادي
# الياسمين
# زهور التوت الأحمر
# الكمثرى
# الأوراق الخضراء
# البرغموت
# الكشمش الأسود
# عصير الأناناس
# الورد
# الياسمين
# السيكلمن
# البرقوق
# خشب الصندل
# البنزوين
# الفانيليا
# المسك
# العنبر
# البرجموت
# أوراق الباتشولي الأندونيسي
# الأخشاب
# العنبر
# رذاذ البحر
# الفلفل الوردي
# الفواكه البرية
# البرجموت الصقلي
# الباتشولي
# المسك
# العنبر
# الكراميل
# الورد
# الياسمين
# البنفسج
# الفراولة
# الكرز
# الأناناس
# اليوسفي
# جلود الغزال
# أخشاب الأرز
# السوسن
# الفلفل
# الوردي
# أخشاب الصندل
# العنبر الكريستالي
# الياسمين
# الكراميل
# العلكة الفقاعية
# التفاح
# المسك
# الأخشاب
# العنبر
# الأزهار
# الألدهيدات
# الورد
# المسك
# ريحان
# ليمون حلو
# روائح فاكهية
# كمون
# أكليل الجبل
# ليمون
# لافندر,زنبق
# أرز بسمتي
# خشب الأرز من فيرجينيا,عنبر
# خشب الصندل
# تفاح
# ياسمين
# العود
# الأخشاب
# العود
# أمبروكسان
# الخشب الكشميري
# المسك
# العود
# البخور
# الجلود
# الأخشاب
# العنبر
# الأعشاب
# شيح
# برغموت
# مكونات فاكهية
# فلفل
# باتشولي
# البلسم المصري
# كراميل
# كمون
# جلد
# يوزو
# رائحه الماء
# البارغموت
# البرتقال الهندي
# يوسفي
# تفاح جراني سميث
# الأناناس
# الكشمش الأسود
# أخشاب الأرز من فرجينيا
# المسك
# خشب الصندل
# الأواكموس- طحلب البلوط
# كحول دينات
# عطر (عطور)
# أكوا (ماء)
# لينالول
# ليمونين
# بوتيل ميثوكسي ديبينزويل ميثان من أصل نباتي 80٪ حجم
# مسك الجلد
# العنبر
# خشب الصندل
# الورد
# أوسمانثوس
# تايجر أوركيد
# المندرين
# زهرة الشاي الأبيض
# البرغموت
# العود
# أوراق
# الباردي
# الكمون
# الفلفل الوردي
# حشائش الورد
# أخشاب
# العود
# الهندي
# القديم
# جوزة الطيب
# الفلفل الأسود
# الفلفل الوردي
# فلفل سيشوان
# الكمون
# الفلفل الوردي
# أنجليكا
# اليانسون
# الكشمش الاسود
# الميموزا
# الورد
# الورد الدمشقي
# البنفسج
# الفانيليا
# المسك
# الزهور البلارية والتركية
# زهور البتول الدمشقية
# السرو
# أخشاب العنبر الجاف
# الكشمير
# اللافندر
# الأزهار الشفافة
# الرذاذ البحري
# البرجموت
# الفواكه المائية
# التفاح الأخضر
# نجيل الهند من هايتي
# خشب الأرز
# الباتشولي
# الليم - الزيزفون
# زهر البرتقال التونسي
# الياسمين
# الأناناس
# البرغموت
# الفلفل الوردي
# العنبر
# نجيل الهند
# المسك
# اللافندر
# الفلفل الأسود
# الزنجبيل
# الليمون
# الجريب فروت
# الماندرين الصقيلي
# لورينوكس
# أخشاب الصندل
# الزنجبيل
# الياسمين المصري
# نبات القلم
# الإيلنغ
# أخشاب الكاشمير
# أوسمانثوس الصيني
# الجلود
# جوز الهند
# الرم
# الباتشولي
# أوراق الخليج
# الياسمين
# الورد
# البارغموت
# زهرة اللاليك
# الاوركيدا
# الفانيلا
# الخوخ
# البرجموت
# الفلفل الوردي
# التوت الأحمر
# الفاونيا
# زنبق الوادي
# زهور سنتيفوليا
# الورد الدمشقي
# أخشاب الصندل
# السوسن
# الباتشولي
# المسك
# خشب
# الصندل
# الورد
# زنبق الوادي
# الإيلنغ
# ياسمين سمباك
# مسك الروم
# البرجموت
# الفلفل الوردي
# برتقال الدم
# العود
# الكشمش الأسود
# أخشاب الصندل
# الفراولة
# شجرة اللوز
# التوت الأسود
# حبوب
# التونكا
# الأخشاب
# العنبر
# الكاكاو
# الجلود
# العنبر
# السوسن
# النرجس
# الزعفران
# البرجموت
# الجريب فروت
# المسك
# الباتشولي
# طحلب السنديان
# زهور مايو
# اللابدانوم
# الليتشي
# الحلبة
# البخور
# أخشاب الصندل
# أخشاب العود
# المر
# العنبر
# جوزة الطيب
# البنزوين
# الأزهار
# الأخشاب
# العود
# الجريب فروت
# البرجموت
# الليتشي
# الياسمين
# الماغنوليا
# اللوتس
# الباتشولي
# زهرة الفريسيا
# توت العلّيق
# ليتشي
# ورد,لقلقي
# شاي,خشب الأرز
# نجيل الهند
# حليب اللوز
# الياسمين
# الزنبق الأبيض
# زهور السوسن
# فانيلا
# العنبر الأبيض
# الماندرين
# الفاوانيا
# الورد
# الفلفل الوردي
# ورد الأوسمانثوس
# باتشولي
# خشب الصندل
# الفانيليا
# نجيل الهند
# خشب الصندل
# العنبر
# أخشاب الأرز
# أخشاب الغاياك
# الزعفران
# القرفة
# البرجموت
# كحول
# عطر
# أكوا (ماء)
# ليمونين
# هيدروكسي سيترونيلال
# سيترونليلول
# هيكسيل سينامال
# إيثيل هكسيل ميثوكسيسينامات
# هيدروكسي إيزوهكسيل 3-سيكلوهكسين كاربوكسالديهايد
# بوتيل فينيل ميثيل بروبيونال
# لينالول
# بوتيل ميثوكسيدينامات السترال
# فارنسول
# نجيل الهند
# الحلوى
# الورد
# البلسم
# أخشاب الأرز
# أخشاب العود
# الزعفران
# التوابل
# نوتات عطرية
# خشب جوزة الطيب
# خشب الأرز و الورد البري
# الماندرين الأخضر
# الزنجبيل الطازج و خشب الأرز
# الفلفل الوردي
# المريمية
# الفانيليا
# العنبر
# التوت الوردي
# الأزهار
# ريحان
# تفاح أخضر
# ليمون
# النعناع والمريمية واللافندر وشجرة الصنوبر
# العنبر والبنزوين
# أناناس
# غريب فروت
# هال,فلفل وردي
# هال,حبوب التونكا
# بتشول
# قرفة
# خشب الأرز
# حبوب التونكا
# الكاكاو
# حلوى اللوز
# مسك الروم
# الورد البلغاري
# الفانيليا
# اللوز
# البرجموت
# القهوة
# الهيلوتروب
# البنفسج الأبيض
# الليلاك
# المسك
# الزنبق
# الفانيليا
# العنبر
# العنبر
# أخشاب الأرز
# المسك الأبيض
# الصفير
# الياسمين
# الورد الأبيض
# الزنبق
# التفاح الأخضر
# كشر الليمون
# البامبو
# الباتشولي
# الماندرين
# البرغموت
# الباتشولي
# المسك
# الجاوي
# بلسم تولو
# نجيل الهند
# المر
# العنبر
# اللابدانوم
# البخور
# القرنفل
# أخشاب الأرز
# زيت سيبرول
# نوتات خضراء
# أوراق البنفسج
# البرجموت
# الماندرين
# الليمون
# إليمي
# ,فاوانيا بيضاء
# سوسن
# جلد الغزال الناعم,عنبر
# مسكون
# خشب الصندل
# الفانيليا
# المسك
# العنبر
# الباتشولي
# التبغ
# الورد
# الياسمين
# أخشاب الصندل
# البرجموت
# الفلفل الوردي
# التفاح
# نجيل الهند
# أخشاب الصندل
# أخشاب الأرز
# الفانيليا
# المسك الأبيض
# المسك
# إبرة الراعي
# الورد
# الورد التركي
# الورد البلغاري
# برجموت كالابريا
# الأوراق الخضراء
# توت العليق
# التوت الأحمر
# الفراولة
# الباشون
# أخشاب الأرز
# المسك
# العنبر
# الفواكه
# موجيت الياسمين
# الورد
# الياسمين
# الليمون
# التفاح
# الجلبانوم
# التاجيت
# خشب الصندل
# المسك
# الكراميل
# اللبن
# الفانيليا
# الورد
# زهور البرتقال
# البنفسج
# الخوخ
# الشمام
# الليمون
# الماندرين
# الراوند
# الكشمش الأسود
# توت العليق
# الأناناس
# الفراولة الكبيرة
# الفواكه
# الجلود
# العنبر
# الفانيليا
# أخشاب الأرز
# المسك
# حبوب التونكا
# الزعفران
# الهيل
# القرفة
# المسك
# العنبر
# السكر
# العود
#  السكر البني
# الباتشولي
# الورد
# الجلود
# حبوب التونكا
# التوابل
# كريم بروليه
# الفانيليا
# الياسمين
# أوركيد الفانيليا
# الروم
# العنبر
# الباتشولي
# السوسن
# التفاح
# العنب
# العصير
# الحلوى
# الآس
# الخزامى
# البرتقال المر
# الليمون
# إكليل الجبل
# اليوسفي
# البرغموت
# بيتوسبوروم
# زهر البرتقال
# الياسمين
# زهرة البرتقال الأفريقية
# أنجليكا
# أمبريت
# العنبر
# البرجموت
# زهور البرتقال
# المسك الأبيض
# الأعشاب العطرية
# الياسمين
# الباتشولي
# البخور
# راتينجات إيلمي
# الكزبرة
# جوزة الطيب
# الرمان
# خشب الصندل
# العود
# الخوخ
# الأناناس
# البرقوق
# الفراولة
# التوت
# التفاح
# الجريب فروت
# البرتقال
# الليمون
# البرغموت
# الجير
# الفلفل الوردي
# الفلفل الأسود
# البتولا
# الأرطماسيا
# القهوة
# الهيل
# القرفة
# القرنفل
# زنبق الوادي
# الورد
# السوسن
# الياسمين
# الماغنوليا
# ا
# الياسمين المصري
# فواكه الغابات
# حبوب التونكا
# مسك الروم
# نجيل الهند
# زهر البرتقال
# الإيلنغ
# الهيل
# القرفة
# الياسمين
# زهرة البرتقال الأفريقي
# حبوب التونكا
# الورد
# المسك
# القزحية
# خشب الصندل
# الجاوي
# الهليوتروب
# أخشاب الأرز
# الصندل
# الراتنجات
# الباتشولي
# المسك
# الورد
# الخوخ
# القرفة
# الياسمين
# البرجموت
# الماندرين
# المسك
# الفانيليا
# التونكا
# العنبر
# أخشاب السدر
# الياسمين
# الكراميل
# القرفة
# اللافندر
# البرجموت
# التفاح
# الهيل
# الخوخ
# ,ورد الشاي
# البردي
# زنبق الوادي
# قصب السكر
# قرفة,مسك
# خشب الأرز
# روائح خشبية
# الباتشولي
# الروم
# اخشاب الأرز والعنبر
# العود
# الأخشاب
# الأوراق الخضراء
# المسك
# المشمش
# الفواكه الحمراء
# الورد
# الفاونيا
# ملح البحر
# الياسمين سامباك
# مسك الروم
# يلانج
# خوخ
# زهر البرتقال
# الأحجار الكريمة السوداء
#  الجلود الحادة
# التوابل
# أخشاب الأرز
# زهور بالما
# الجريب فروت
# النيرولي
# الزعتر
# الزعفران
# البرجموت
# اللبادنوم
# إبرة الراعي
# اللافندر
# خشب الأرز
# أمبروكسان
# الجلود
# البلوط
# نجيل الهند
# أخشاب الصندل
# الرم
# السوسن
# إبرة الراعي
# اللافندر
# المريمية
# الهيل
# كحول
# عطر
# ليمونين
# أكوا (ماء)
# لينالول
# سيترال
# بوتيل ميثوكسيديبنزويل ميثان
# جيرانيول
# سيترونيلول
# فارنسول
# البرغموت
# الليمون
# إبرة الراعي
# اللافندر
# الأرز
# الياسمين
# التفاح
# زنبق الوادي
# العنبر
# الطحلب
# نفحات البحر
# خشب الصندل
# العنبر
# خشب الصندل
# نجيل الهند
# طحلب البلوط
# زنبق الوادي
# إبرة الراعي
# اليوسفي
# اللافندر
# الريحان
# الليمون
# حبوب التونكا
# المسك
# العنبر
# الفانيليا
# الورد
# الياسمين
# مسك الروم
# أخشاب الصندل
# الليمون
# البرجموت
# القهوة
# الكاكاو
# اللوز
# التفاح
# البرغموت
# الأوريجانو
# اللابدانوم
# الفانيليا
# خشب الأرز
# الباتشولي
# الروائح الخشبية
# العود
# خشب الصندل
# المسك
# أوراق البنفسج
# الجلود
# العود
# القهوة
# الشيكولاتة
# الأزهار
# ,ورد
# رمان
# زهرة الياقوتية الوردية,أمبروكسان
# خشب الأرز
# مسك
# العنبر
# المسك
# الأرز
# طحلب البلوط
# المانغوليا
# الورد الدمشقي
# الليتشي
# الجريب فروت
# الورد
# أوراق نبات الفراولة,زهر البرتقال ,برالين
# فانيليا
# المسك
# زهور الكرز
# الورد
# هورتنسيا
# الكرز
# برتقال دموي
# غريب فروت
# ليمون
# إجاص,ياسمين عربي مطلق,بتشول اندونيسي
# مسك
# الباتشولي
# المسك
# العنبر
# زنبق الوادي
# الورد
# الزعفران
# الياسمين
# الفلفل الوردي
# البرجموت
# أخشاب الأرز البرازيلية
# المارتيني
# البرجوت
# اللافندر
# الماندرين
# النرجس
# الأوركيد
# الباتشولي
# العنبر
# خشب الأرز
# الأخشاب
# المسك

# %%
# df = df.reset_index(drop=True)

# %%
# all_comp = []

# %%
# for element in df['المكونات']:
#     for i in element:
#         if not i in all_comp:
#             all_comp.append(i)

# %%
# len(all_comp)

# %%
# len(set(all_comp))

# %%
# df.shape

# %%
# new = []
# for i in all_comp:
#     if ' و' in i:
#         a = i.split(' و')
#         new.extend(a)
#     else:
#         new.append(i)

# %%
# all_comp = set(new)
# all_comp = list(all_comp)
# all_comp

# %%
# for i in all_comp:
#     df[i] = False

# %%
# for i in df.columns:
#     if '.' in i:
#         print(i.replace('.', ''))
