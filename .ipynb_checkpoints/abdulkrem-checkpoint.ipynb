# %%
import warnings

import numpy as np
import pandas as pd

# %%
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('golden_scent_perfumes2.csv')

# %%
df.head(2)
# Out:
#                             الاسم  السعر النهائي      الماركة        الجنس  \
# 0  كورلوف كوير ميثيك أو دو برفيوم           1116       كورلوف  رجالي/نسائي
# 1        كالفين كلاين ايفوريا ومن            298  كالفن كلاين        نسائي
#
#   نوع المنتج شخصية عطرك العائلة العطرية   الحجم سنة الإصدار  نسبة التركيز  \
# 0       عطور   كلاسيكية           جلدية  100 مل        2018  أو دو برفيوم
# 1       عطور      حيوية          فاكهية   50 مل        2005  أو دو برفيوم
#
#    ... قاعدة العطر Category                                       المكونات  \
# 0  ...      الجلود      NaN                                            NaN
# 1  ...  عنبر ، خشب     عطور  رمان ، لوتس بلوسوم ، بلاك أوركيد ، عنبر ، خشب
#
#   اللون النوتات العُليا النوتات المتوسطة النوتات القاعدية التركيبة  \
# 0   NaN             NaN              NaN              NaN      NaN
# 1   NaN             NaN              NaN              NaN      NaN
#
#   نوع المكياج مفتاح البحث
# 0         NaN         NaN
# 1         NaN         NaN
#
# [2 rows x 22 columns]

# %%
df.shape#.sort_values(ascending = False)
# Out:
# (8144, 22)

# %%
df['الجنس'].fillna('لا توجد معلومات', inplace=True)

# %%
df['شخصية عطرك'].fillna('لا توجد معلومات', inplace=True)

# %%
df['العائلة العطرية'].fillna('لا توجد معلومات', inplace=True)

# %%
df['نسبة التركيز'].fillna('لا توجد معلومات', inplace=True)

# %%
df = df[df['نوع المنتج'] == 'عطور']

# %%
#################################################################################

# %%
df.drop('نوع المنتج', axis = 1, inplace = True)

# %%
df.drop('سنة الإصدار', axis = 1, inplace = True)

# %%
df.drop('اللون', axis = 1, inplace = True)

# %%
df.drop('Category', axis = 1, inplace = True)

# %%
df.drop('النوتات العُليا', axis = 1, inplace = True)

# %%
df.drop('النوتات المتوسطة', axis = 1, inplace = True)

# %%
df.drop('النوتات القاعدية', axis = 1, inplace = True)

# %%
df.drop('التركيبة', axis = 1, inplace = True)

# %%
df.drop('نوع المكياج', axis = 1, inplace = True)

# %%
df.drop('مفتاح البحث', axis = 1, inplace = True)

# %%
#################################################################################

# %%
df = df.reset_index(drop=True)

# %%
df.head(2)
# Out:
#                             الاسم  السعر النهائي      الماركة        الجنس  \
# 0  كورلوف كوير ميثيك أو دو برفيوم           1116       كورلوف  رجالي/نسائي
# 1        كالفين كلاين ايفوريا ومن            298  كالفن كلاين        نسائي
#
#   شخصية عطرك العائلة العطرية   الحجم  نسبة التركيز  \
# 0   كلاسيكية           جلدية  100 مل  أو دو برفيوم
# 1      حيوية          فاكهية   50 مل  أو دو برفيوم
#
#                   مقدمة العطر                     قلب العطر قاعدة العطر  \
# 0  الماندرين، الصنوبر، العرعر  الزنجبيل، الجلابانوم، السوسن      الجلود
# 1                        رمان     لوتس بلوسوم ، بلاك أوركيد  عنبر ، خشب
#
#                                         المكونات
# 0                                            NaN
# 1  رمان ، لوتس بلوسوم ، بلاك أوركيد ، عنبر ، خشب

# %%
#################################################################################

# %%
gender = {}

# %%
counter = 1

# %%
for b in df.groupby(by = 'الجنس').size().index:
    if b == 'لا توجد معلومات':
            gender['لا توجد معلومات'] = 0
    else:
        gender[b] = counter
        counter = counter + 1

# %%
gender = dict(sorted(gender.items(), key=lambda x:x[1]))

# %%
for first_key, first_item in gender.items():
        df.loc[df['الجنس'] == first_key, 'الجنس'] = first_item

# %%
df = df.astype({ "الجنس" : "int64" })

# %%
#################################################################################

# %%
character = {}

# %%
counter = 1

# %%
for b in df.groupby(by = 'شخصية عطرك').size().index:
    if b == 'لا توجد معلومات':
            character['لا توجد معلومات'] = 0
    else:
        character[b] = counter
        counter = counter + 1

# %%
character = dict(sorted(character.items(), key=lambda x:x[1]))

# %%
for first_key, first_item in character.items():
        df.loc[df['شخصية عطرك'] == first_key, 'شخصية عطرك'] = first_item

# %%
df = df.astype({ "شخصية عطرك" : "int64" })

# %%
#################################################################################

# %%
family = {}

# %%
counter = 1

# %%
for b in df.groupby(by = 'العائلة العطرية').size().index:
    if b == 'لا توجد معلومات':
            family['لا توجد معلومات'] = 0
    else:
        family[b] = counter
        counter = counter + 1

# %%
family = dict(sorted(family.items(), key=lambda x:x[1]))

# %%
for first_key, first_item in family.items():
        df.loc[df['العائلة العطرية'] == first_key, 'العائلة العطرية'] = first_item

# %%
df = df.astype({ "العائلة العطرية" : "int64" })

# %%
#################################################################################

# %%
percentage = {}

# %%
counter = 1

# %%
for b in df.groupby(by = 'نسبة التركيز').size().index:
    if b == 'لا توجد معلومات':
            percentage['لا توجد معلومات'] = 0
    else:
        percentage[b] = counter
        counter = counter + 1

# %%
percentage = dict(sorted(percentage.items(), key=lambda x:x[1]))

# %%
for first_key, first_item in percentage.items():
        df.loc[df['نسبة التركيز'] == first_key, 'نسبة التركيز'] = first_item

# %%
df = df.astype({ "نسبة التركيز" : "int64" })

# %%
#################################################################################

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8143 entries, 0 to 8142
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   الاسم            8143 non-null   object
#  1   السعر النهائي    8143 non-null   int64
#  2   الماركة          8135 non-null   object
#  3   الجنس            8143 non-null   int64
#  4   شخصية عطرك       8143 non-null   int64
#  5   العائلة العطرية  8143 non-null   int64
#  6   الحجم            8125 non-null   object
#  7   نسبة التركيز     8143 non-null   int64
#  8   مقدمة العطر      6170 non-null   object
#  9   قلب العطر        6114 non-null   object
#  10  قاعدة العطر      6116 non-null   object
#  11  المكونات         4552 non-null   object
# dtypes: int64(5), object(7)
# memory usage: 763.5+ KB

# %%
#################################################################################

# %%
def toLi(x):
    col = 'مقدمة العطر'
    if not pd.isna(x[col]):
        x[col].replace('.', '')
        if '،' in x[col]:
            x = x[col].split('،')
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
        elif ',' in x[col]:
            x = x[col].split(',')
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
        else:
            x = x[col].split()
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
    else:
        return x[col]

# %%
df['مقدمة العطر'] = df.apply(toLi, axis=1)

# %%
#################################################################################

# %%
def toLi(x):
    col = 'قلب العطر'
    if not pd.isna(x[col]):
        x[col].replace('.', '')
        if '،' in x[col]:
            x = x[col].split('،')
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
        elif ',' in x[col]:
            x = x[col].split(',')
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
        else:
            x = x[col].split()
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
    else:
        return x[col]

# %%
df['قلب العطر'] = df.apply(toLi, axis=1)

# %%
#################################################################################

# %%
def toLi(x):
    col = 'قاعدة العطر'
    if not pd.isna(x[col]):
        x[col].replace('.', '')
        if '،' in x[col]:
            x = x[col].split('،')
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
        elif ',' in x[col]:
            x = x[col].split(',')
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
        else:
            x = x[col].split()
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
    else:
        return x[col]

# %%
df['قاعدة العطر'] = df.apply(toLi, axis=1)

# %%
#################################################################################

# %%
def toLi(x):
    col = 'المكونات'
    if not pd.isna(x[col]):
        x[col].replace('.', '')
        if '،' in x[col]:
            x = x[col].split('،')
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
        elif ',' in x[col]:
            x = x[col].split(',')
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
        else:
            x = x[col].split()
            a = []
            for i in x:
                if not i == '':
                    if i[0] == ' ':
                        i = i[1:]
                if not i == '':
                    if i[-1] == ' ':
                        i = i[:-1]
                    a.append(i)
            return a
    else:
        return x[col]

# %%
df['المكونات'] = df.apply(toLi, axis=1)

# %%
#################################################################################

# %%
df['المكونات'].fillna(False, inplace=True)

# %%
df['مقدمة العطر'].fillna(False, inplace=True)

# %%
df['قلب العطر'].fillna(False, inplace=True)

# %%
df['قاعدة العطر'].fillna(False, inplace=True)

# %%
#################################################################################

# %%
df = df.reset_index(drop=True)

# %%
#################################################################################

# %%
for ind in df.index:
    row = df.loc[ind, ['المكونات', 'مقدمة العطر', 'قلب العطر', 'قاعدة العطر']]
    if not row['المكونات']:
        if row['قاعدة العطر'] and row['قلب العطر'] and row['مقدمة العطر']:
            result = row['قاعدة العطر'] + row['قلب العطر'] + row['مقدمة العطر']
            df.at[ind,'المكونات'] = result

# %%
#################################################################################

# %%
mask = df[df['المكونات'] == False].index

# %%
df.drop(mask , inplace=True)

# %%
df[df['المكونات'] == False]
# Out:
# Empty DataFrame
# Columns: [الاسم, السعر النهائي, الماركة, الجنس, شخصية عطرك, العائلة العطرية, الحجم, نسبة التركيز, مقدمة العطر, قلب العطر, قاعدة العطر, المكونات]
# Index: []

# %%
df = df.reset_index(drop=True)

# %%
all_comp = []

# %%
for element in df['المكونات']:
    for i in element:
        if not i in all_comp:
            all_comp.append(i)

# %%
len(all_comp)
# Out:
# 6616

# %%
len(set(all_comp))
# Out:
# 6616

# %%
df.shape
# Out:
# (7806, 12)

# %%
new = []
for i in all_comp:
    if ' و' in i:
        a = i.split(' و')
        new.extend(a)
    else:
        new.append(i)

# %%
all_comp = set(new)
all_comp = list(all_comp)
all_comp
# Out:
# ['',
#  'المارشيمللو.',
#  'المسك الرومي',
#  'النبيذ',
#  'اليلانغ-يلانغ',
#  'الهيليوتروب',
#  'مزيج الرمل الأيبض,مرمرية',
#  'جنين القمح التونسي',
#  'خشب الاجار',
#  'هياسينث',
#  'البنات',
#  'توت العلّيق',
#  'اللافندر الأبيض',
#  'الماغنوليا البيضاء',
#  'غرنوقي زهرة',
#  'زهر البرتقالالياسمين',
#  'البنفسج الأسود',
#  'نبيذ أبيض,فاوانيا',
#  'أرز بسمتي',
#  'الفرنجباني',
#  'نجيل الهند المذكر',
#  'خشب الماهوجني',
#  '\xa0العنبر',
#  'بيتيل ميثوكسيدينزويثان',
#  'دهن العود',
#  'بذر اليانسون',
#  'أعواد الفانيليا.',
#  'الكرز.',
#  'شيح,قرنفل',
#  'العنبر المكثف',
#  'ورد الجوري',
#  'الفلفل الكرزي',
#  'أخشاب الأرز البيضاء',
#  'والأوركيد',
#  'توت كرز الرمان',
#  'الكبوسين أبو خنجر',
#  'بودرية',
#  'بلوميريا',
#  'الكحول المغير',
#  'خلاصة البيمينتو الحار',
#  'والسوسن',
#  'الكاليبسون',
#  'مستخلصات زهرة التوت',
#  'زنبق الماء الأزرق',
#  'زهور ألبا البيضاء',
#  'أشجار الأرز',
#  'زهور بريه',
#  'نرجس بري من فرنسا',
#  'إيثيل هيكسيل ميثوكسيسينامات',
#  'رذاذ البحر,حشب الأرز',
#  'عطر دينات',
#  'المتيمة',
#  'وولفوود',
#  'اللبدانوم الفرنسي',
#  'زهرة الفانيلا',
#  'تناسب',
#  'اللاڤندر',
#  'التوت الأسود',
#  'الأمارلس البيضاء',
#  'ألكولز',
#  'Egyptian Jasmine',
#  'الفواكه الغريبة',
#  'يلانج- يلانج',
#  'الورد الأسود',
#  'البوربون',
#  'Champaka',
#  'زهور شجر الكمثرى',
#  'روائح أوراق الشجر الخضراء',
#  'البرتقال الاحمر',
#  'بذر الكرفس',
#  'فانيليا مدغشقرية',
#  'ميثيل',
#  'حلوى اللوز',
#  'Flowers',
#  'gardenia',
#  'مكونات الياسمين الإيطالي',
#  'خشب بيرش',
#  'ليمون',
#  'بذور الجزر.',
#  'مشمش',
#  'صمغ القرفة',
#  'زنبق الوادى',
#  'هال غواتيمالا',
#  'سيريوس',
#  'الفرواله',
#  'أخشاب الصنجل',
#  'مدقة الزنبق',
#  'المكنسة',
#  'سامباك ياسمين',
#  'كشمش أحمر,زهرة يلانغ يلانغ,قريضة',
#  'ينسون,جلد',
#  'طحلب البوط',
#  'الشفاه',
#  'خشب أبيض',
#  'زهور البرسيم',
#  'نفحات من العنبر',
#  'البرتقال الإيطالي',
#  'الكشمير',
#  'ذرات ترابية',
#  'زهرة القرنفل',
#  'الليمون اللإيطالي',
#  'أوراق النخيل',
#  'الكسبرة',
#  'زهر البتولا',
#  'ماغنوليا حلوة,إيلانغ,روائح خشبية',
#  'أمبرجريس',
#  'العريقة',
#  'الفراوله الياسمين',
#  'Green Leaves',
#  'أوركيد الفانيليا',
#  'خشب الأبانوس',
#  'بذر اليانسون,خوخ',
#  'الكراوية',
#  'ماء زهر البرتقال',
#  'الجواتيمالي',
#  'الورق المحترق',
#  'الافندر',
#  'كريست مارين',
#  'عود العنبر',
#  'ابراعي الراعي',
#  'بنزازول الأوجينول',
#  'الأيزو',
#  'الفانيليا البودرة',
#  'الزهور البرية',
#  'كريم بروليه',
#  'صمغ الجلبانوم',
#  'طحلب أبيض.',
#  'والميرامية',
#  'أخشاب إفريقية',
#  'زهور التفاح',
#  'أوراق الكشمش الأسود,خشب الصندل ميسور',
#  'راتنج الإيليمي',
#  'زيت الحبق',
#  'نجيب الهند',
#  'اخشاب المسك الابيض',
#  'الأرز الأطلسي',
#  'صبغة الورد',
#  'الدرنة',
#  '\u200b\u200bبابريكا',
#  'بوربون الفانيليا',
#  'ينسون نجمي,فانيلا',
#  'بندق ,جلد',
#  'الشاي البري المجمد',
#  'فواكه غريبة',
#  'توت بري',
#  'الياسمين المائي',
#  'الأوسمانثوسالعنبر',
#  'ذهب الشمس',
#  'أخشاب فيرا',
#  'التبغ, الجزر',
#  'مائية',
#  'فرانجبياني',
#  'حلوي البرالين',
#  'الزهور الخشبية',
#  'القرنفل الهندوسي',
#  'أخشاب الآراك.',
#  'العسل',
#  'الفلفل الوردي الحار',
#  'Magnolia',
#  'الأحشاب',
#  'الفانيليا',
#  'الفلفل البربوني',
#  'أوراق بوميلو',
#  'شجر الورد',
#  'زهر البرتقال الإفريقي',
#  'الفواكه المائية',
#  'عسل,نجيل الهند',
#  'باشن فروت',
#  'توت العلّيق,ياسمين',
#  'زهرة الجراس',
#  'لوز أخضر',
#  'الباتليا',
#  'أخشاب الصنوبر',
#  'اخشاب',
#  'Orange Blossom',
#  'تريس',
#  'بوتيل ميثوكسيديبينزوييلثين',
#  'Woods',
#  'أرز',
#  'فلفل أحمر',
#  ' زهور سويسرية',
#  'الشمام',
#  'الخشب.',
#  'خلاصات زهريّة',
#  'توت العلّيق,لوز',
#  'المسك ذو الرائحة البودرية الحلوة',
#  'جريب فروت البنفسج',
#  'السوسن المركز',
#  'ردي,إيفرينا خوخية',
#  'الخوخ',
#  'زهرة باشون',
#  'امبركسان',
#  'ليزر',
#  'فاكهة الباشون',
#  'براعم الكرز',
#  'الهليوتروب',
#  'شجر الويستاريا.',
#  'شربات الكشمش الأسود',
#  'السنط',
#  'طلاء الورنيش',
#  'توفي',
#  'الويسكي',
#  'التنوب الأزرق السيبيري',
#  'يوسفي ايطالي',
#  'رذاذ الطلاء',
#  'شجرة اللوز',
#  'خشب أكاجو',
#  'خوخ,ياسمين',
#  'الأخشاب الكريمية',
#  'أوراق الفاكهة',
#  'العود الكشميري',
#  'حبوب الكاكاو',
#  'الورد البرتغالي',
#  'حلوي الكراميل',
#  'ألفا إيزوميثيلينون',
#  'الزنبق التيجي',
#  'أمالفي ليمون',
#  'براعم الياسمين',
#  'فلفل حلو,ورد بلغاري',
#  'والورد',
#  'زهور ليتشي',
#  'التونسي',
#  'اكوا',
#  'مياه المحيطات',
#  'الكشش الأسود',
#  'شجرة البتولا',
#  'الباتشول',
#  'سيدرات',
#  'زهرة جوزة الطيب',
#  'قصب السكر',
#  'موس',
#  'بذور العنب',
#  'التاهيتي',
#  'بوربون',
#  'فواكة جافة,جاردينيا,إيفرينا خوخية',
#  'زهور البرية',
#  'جوز الهند الأبيض',
#  'كالابريان الماندرين',
#  'عطر البرتقال الحلو',
#  'شجر المُر',
#  'أرزينيا',
#  'أوراق أمبرين الخشبية.',
#  'الماندرين الأخضر',
#  'الأغاف',
#  'سيتالوكس.',
#  'زهرة الحارقة',
#  'نبتة العقبة',
#  'الوستاريه',
#  '/',
#  'الأخشاب',
#  'دينامون بلأمبر',
#  'خمرة ,جلد',
#  'المسكي',
#  'جادور.',
#  'الروائح البحرية',
#  'زهرة الزنجبيل',
#  'الزميل',
#  'خشب الأرز الأطلسي,جلد',
#  'عود السلطان',
#  'الكراميل المملح',
#  'فلفل أسود مدغشقري',
#  'Sea Notes',
#  'قطرات المياه',
#  'زنابق الأوركيد',
#  'الراتينج',
#  'سكر',
#  'بيتوسبوروم',
#  'بربون إبرة الراعي',
#  'بابونج',
#  'ونابق الوادي',
#  'اللبلاب',
#  'المولت',
#  'المسك العربي',
#  'الجلود الإيطالية',
#  'زهور الفريجيا',
#  'زهر البرتقال الأفريقي الغني',
#  'المكياج',
#  'زهور الكمثرى',
#  'اخشاب الورد من بالي',
#  'أزهار البرتقال التونسية',
#  'الآيريس',
#  'رد باليساندر',
#  'الكمثري.',
#  'جادور',
#  'سيترونيل. ساليسيلات',
#  ' الباتشولي',
#  'إبرة',
#  'Cedar',
#  'Orris',
#  'المسكرة',
#  'أوراق الكشمش الأسود',
#  'ورد غراس',
#  'الفواكه الإستوائية',
#  'بلسم اللابدانوم',
#  'هال,فلفل',
#  'إيثيلهيكسيل ميثوكسيسينامات',
#  'السوسن الإيطالي',
#  'والكمثرى',
#  'ريحان',
#  ' الزعفران',
#  'الدمشقي',
#  'جلاكسوليد',
#  'رائحة الماء',
#  'الكاسيس',
#  'إيلمي',
#  'العليق الأسود',
#  'Bergamot',
#  'البنزيل',
#  'قرنفل مدغشقر',
#  'الباتشولي الأشقر',
#  'الجريب فروت',
#  'لينالول - ليمونين - سيترونيلول - جيرانيول - ميثيل 2-أوكتينوات.',
#  'النوتات البحرية',
#  'إيثيل هيكسيل ساليسيلات',
#  'الهليوتروب الأبيض',
#  'ليمون لويزة',
#  'بوربون نجيل الهند ,خشب الكشمير',
#  'زهرة البرتقال الأفريقية',
#  'التوت المعجزة',
#  'Woody notes',
#  'بوتيل ميثوكسيديبنزوييلثين',
#  'الهندي',
#  'الأدرينالين',
#  'خلاصة الزعتر',
#  'الأسفلت',
#  'أعشاب طازجة',
#  'خشب خفيف',
#  'مسك ابيض',
#  'البرغموت (الحمضيات)',
#  'أوركيد بري',
#  'شجرة',
#  'الليتسيا كوبيبا,مسك',
#  'ميثيل إيثيلهيكسيل ميثوكسيزينامير',
#  'أوراق العنب',
#  'خشب العود (العود)',
#  'الكراوية.',
#  'الزعفران .',
#  'المشمش',
#  'مانجو',
#  'الفاوانيا البيضاء',
#  'أمبروفكس',
#  'زهور مائية',
#  'كاميليا',
#  'العود النيبالي',
#  'نعناع,فاوانيا',
#  'الأعشاب',
#  'حشب الصندل',
#  'oak moss',
#  'براعم الكرز الياباني',
#  'نجيل الهند الأطلسي',
#  'أخشاب الباتشولي',
#  'الكاكاو.',
#  'المشمش الأسود',
#  'زنبق الماء',
#  'الخزامى',
#  'الياسمين المصري المطلق',
#  'براعم اللوز',
#  'الايلينغ',
#  'Moujan',
#  'زهرة الياقوتية',
#  'البرقوق المجفف',
#  'وودي',
#  'أعشاب البحر',
#  ' الورد',
#  'بنتاريثرتييل تترا دي تي بيوتيل هيدروكسي هيدروكينامات',
#  'سيترال سيترونيلول',
#  'هيكسيل بنزوات',
#  'أخشاب الصندل الاستوالي',
#  'شاي إرل غري',
#  'بنزيل بنزوات رودز',
#  'براعم ليندن,روائح زهرية',
#  'نجيل الهند هياتي.',
#  'الروبراب',
#  'رد',
#  'العشب الأخضر',
#  'Cardamom',
#  'إل إينالول',
#  'الكزبرة',
#  'الأخشاب الغريبة',
#  'سيدار',
#  'يانسون',
#  'Chestnut cream',
#  'الموسمية',
#  'إيزوجينول.',
#  'ياسمين',
#  'زهور الخوخ',
#  'زهور الزنبق',
#  'حلوى بانا كوتا',
#  'الكمأة',
#  'خشب غاياك,بتشول',
#  'الجوري',
#  'زهور سنتيفوليا',
#  'نبات بحري',
#  'سيبريس',
#  'زهر البرتقال فريزيا',
#  'التبغ الأسباني',
#  'أشجار الصنوبر',
#  'سويد',
#  'ألفا-أيزو ميثيل أيونون',
#  'التوت المثلج',
#  'الياسمين الشمسي',
#  'الفواكه.',
#  'أيزويوجينول',
#  'رعي الحمام',
#  'رائحة الزباد',
#  'تحوي',
#  'البخور الأبيض',
#  'السيلكوليد (المسك)',
#  'العنبر الفانيليا',
#  'أزهار الجريب فروت',
#  'تونكا محمص.',
#  'النعمان',
#  'نارجيل الهند',
#  'الأوراق المنعشة',
#  'الفراولة البرية',
#  'إكليل الجبل.',
#  'Kumquat',
#  'المسك الخشبي',
#  'طحلب الكريستال',
#  'التفاح الأحمر',
#  'نفحات زهرية',
#  'زيت أخشاب الغاياك',
#  'الماهوجني',
#  'العنبر الرمادي.',
#  'فريسيا',
#  'المثلج',
#  'الورد البري',
#  'Wood',
#  'البتولا.',
#  'زهور الباشون',
#  'أكيجالا',
#  'المكونات الحمضية',
#  'الأوكالبتوس.',
#  'قهوة',
#  'اخشاب السدر',
#  'زهور الياقوت النادرة',
#  'زهور الجريب فروت',
#  'هيدروكسي إيثيول إيزيولوجين.',
#  'سويتشونج',
#  'النفحات المائية',
#  'أوريس',
#  'زهرة الصحراء',
#  'الزهور المورقة',
#  'النرجس.',
#  'الأزهار البيضاء',
#  'بوتيل هيدروكسيتولوين',
#  'الشربات',
#  'خمرة,روائح زهرة الأوركيد',
#  'وإبرة',
#  'ليلي',
#  'الزعفران الهندي',
#  'الجافة',
#  'الأخشاب المجروفة',
#  'الهيل الأخضر',
#  'ورد مسك',
#  'شاي أسود,زهرة الأبدية',
#  'الورد',
#  'دافانا',
#  'والكمون',
#  'الليمون.',
#  'الراتنجات الحلوة. ياسمين سمباك',
#  'نيرولي',
#  'كسر العود',
#  'الجوافة',
#  'فول',
#  'راتنج التنوب',
#  'طحلب شجرة المسك',
#  'كالابريان برغموت',
#  'التاجتس',
#  'شوكولا',
#  'Mimosa',
#  'الزعتر.',
#  'براعم اللافندر',
#  'زهور الأوركيد السوداء',
#  'كاسيس',
#  'رائحة حلوى الشربات المثلج',
#  'شاي سيلان',
#  'الخيار الطازج',
#  'أوسمانثوس',
#  'الفاوانيا الوردية',
#  'لبن',
#  'تيراميسو',
#  'عنبر أبيض,عنبر',
#  'زهرة الداتورة',
#  'الصينية',
#  'خشب الصندل الكاشميري',
#  'بتلات السوسن',
#  'عنب الثعلب',
#  'جذور',
#  'الفريزيا الزهرية',
#  'سينامال الأميل',
#  'مر',
#  'أخشاب العنبر الجاف',
#  'زهرة اوسمانثوس الحلوة',
#  'النفحات الخشبية.',
#  ',مريمية',
#  'برتقال دم الزغلول',
#  'اليلنغ يلنغ',
#  'خشب لورو أماريلو',
#  'الوردة البلغارية',
#  'الأخشاب المحروقة',
#  'الليمون لويزة',
#  'الياسمينالفانيليا',
#  ' السكر البني',
#  'خضرة',
#  'ميثوكسي ديبينزويل ميثان',
#  'البابونج',
#  'بتيتغرين',
#  'لبان أوليبانوم,خشب الصندل',
#  'الكابتشينو',
#  'الورد الشرقي',
#  'قرنفل السوسن',
#  'الدفانا',
#  'Amalfi Lemon',
#  'مريمية,الورد البلغاري',
#  'الثمينة',
#  'إفرنيا بروناستري',
#  'البن المحمص',
#  'شاي إيرل جراي',
#  'Tuberose',
#  'مادونا ليلي زنبق الوادي ياسمين',
#  'سيكلوهكسين كاربوكسالديهايد',
#  'الورد الحلو',
#  'شمر',
#  'بوتيل ميثوكسيدينامات السترال',
#  'مركب العنبر (أوبرانيد',
#  'البلاب',
#  'الموز',
#  'البليني',
#  'رائحة الثلج',
#  'العنبر.',
#  'السكريات',
#  'الماندرين البرتقالي',
#  'كشميران',
#  'روائح حلوة',
#  'Davana',
#  'عبير البودر',
#  'الغار',
#  'الكيوي',
#  'حب المسك',
#  'بتلات الغاردينيا, خشب الأرز التاكسسي',
#  'الكستاء',
#  'زهرة البرتقال',
#  'وخشب الصندل',
#  'ناشي الكمثرى',
#  'دينات الكحول. (كحول Sd 39-C)',
#  'الفاوانيا.',
#  'توت بري ,زهرة الغرنوقي',
#  'خلاصة الفانيليا',
#  'الخشب الأحمر البرازيلي',
#  'نفحات سكرية',
#  'ألفا-ايزوميثيل ايونون',
#  'زهرة بافوت,بتشول',
#  'أزهار شجرة الخوخ',
#  'ليمون,',
#  'قلب نجيل الهند',
#  'المانجو الخضراء الاستوائية',
#  'ورق الغار,غرنوقي',
#  'جوزة الطيب.',
#  'لينولول.',
#  'الأمبريتوليد',
#  'الاخشاب الثمينة',
#  'المكونات الخشبية.',
#  'خشب الورد البالي',
#  'بنفسج,فانيليا',
#  'مسحوق الفانيليا',
#  'زهر اللوز',
#  'الجاوي الأحمر',
#  'زنبق الوادى,مسك',
#  'مزيج السيدر',
#  'مربى الكاسيس',
#  'بنزوفينون -3',
#  'بوتيل',
#  'النجارمثا',
#  'الصندل الليموني',
#  'الكاراميل.',
#  'والهيل',
#  'المسك المخملي الحلو',
#  'شجر الكاري',
#  'أستراكس',
#  'وأوراق',
#  'أكوا (الماء)',
#  'خشب الأرز من فرجينيا',
#  'زهور جينية',
#  ' الاخشاب الشرقية',
#  'المغربي',
#  'الزنجبيل الأبيض الليلي',
#  'سيلان',
#  'التبغ البرازيلي',
#  ' المسك.',
#  'البرازيلي',
#  'زهر البرتقال.',
#  'بنتاريثرتييل تترا دي تي بيوتيل.',
#  'النوتات الزهرية',
#  'لوستارية',
#  'Floral',
#  'الزباد الاصطناعي',
#  'روائح بحرية',
#  'شجر الكينا',
#  'كمون',
#  'بهارات',
#  'زنبق اولادي',
#  'الفاونيا',
#  'الماندرين.',
#  'عطر (عطور)',
#  'زهور بروم',
#  'والمشمش',
#  'إبر الأرز',
#  'ل',
#  'أوراق البنفسج المصري',
#  'نخالة القمح',
#  'يوسفي,سوسن',
#  'زهور البرتقال التونسي',
#  'مكونات خضراء',
#  'كحول أميل سيناميل',
#  'عنبر إكستريم',
#  'البرتقال الذهبي',
#  'المانجو',
#  'بنزيل بنزوات',
#  'خزامى',
#  'بتلات الأزهار',
#  'مرميه',
#  'باي ليف',
#  'الخروع',
#  'أخشاب جاياك',
#  'برغموت الايطالي',
#  'الأكورد',
#  'البتيتغرين',
#  'الدهيدات',
#  'فاكهة البيشن',
#  'الروائح الخشبية من الباتشولي الإندونيسي',
#  'ليمون,مسك التونكن',
#  'الأوسمانثوس',
#  'هكسيل سينامال',
#  'ناجارموثا',
#  'أوركيد التوت',
#  'الجزر البذور.',
#  'اللابدنوم',
#  'الأوراق الخضراء',
#  'نجيل الهند.',
#  'مسك القطن',
#  'المر الذهبي',
#  ',روز اسنتيل™ LMR',
#  'شيح,لافندر',
#  'نيرولي,مسك أبيض',
#  'مرمرية كلاري,خشب الكشمير',
#  'البنفسج المطلق',
#  'ليمون سيسيليا',
#  'زهر البرتقال المغربي',
#  'زهور فواكه',
#  'العنبر الكهرماني',
#  'بوماروس',
#  'زهر بخور مريم',
#  'زهور التوت الأسود',
#  'جلد أسود',
#  'العود المخملي',
#  'شوكولاتة',
#  'الزهور.',
#  'كشمش أسود,طحلب البلوط',
#  'الليمونين',
#  'لافندر',
#  'اللابدانوم العربي',
#  'عنبر أوكس',
#  'تريس (هيتراميثيل هيدروكسي بيبيريدينول) سيترات',
#  'الأخشاب النادرة',
#  'زهر السوسن',
#  'الجلد السويدي الأبيض',
#  'بوغانفيليا',
#  'Violet Leaves',
#  'شمع الخشب',
#  'جوزة الطيب,غاردينيا',
#  'أيزو إي سوبر',
#  'شراب الكرز',
#  'خشب الأرز.',
#  'العطرية',
#  'دهن',
#  'Oakmoss',
#  'جلد روسي,عود مدخن',
#  'أوسمانثوس الصينية',
#  'سترال',
#  'النيورلي',
#  'كحول ا',
#  ' دهن العنبر.',
#  'البتشول الأندنوسي',
#  'وردية',
#  'كحول',
#  ' الميموزا',
#  'زهور العنب',
#  'القرنفل الملون',
#  'جاوشير',
#  'سترونيلول',
#  'السيترات ثلاثي إيثيل',
#  'الزعفرا',
#  'السيجار',
#  'Fig',
#  'مرمرية,نجيل الهند',
#  'جرانيول',
#  'نسيم البحر',
#  'Lotus',
#  'وردة زهرية',
#  'زباد',
#  'توكوفيرول',
#  'ألكسيليت) سترات',
#  'كالابريا البرغموت',
#  'المطلقة',
#  'البرجموت الإيطالي',
#  'بيلادونا',
#  '\xa0طحلب\xa0البلوط',
#  'الشيكولاته الغامقه',
#  'غوارانا',
#  'رقيب الشمس ,خشب العود',
#  'الكركديه الاحمر',
#  'رذاذ الماء',
#  'الطحلب الأبيض',
#  'روائح البحر',
#  'إكليل الجبل,مسك الروم',
#  'د-ليمونين',
#  'امبروكس سوبر',
#  'Lemon',
#  'الطحالب',
#  'مالتول',
#  ' الكاسي',
#  'أيزووجينول',
#  'تشينوتو',
#  'مستكه',
#  'الياسمين الصيني.',
#  'الياسمين الكاريبي',
#  'أخشاب الصندل الأبيض',
#  'الفتاح الأخضر',
#  'أعواد',
#  'الأوراق المطحونة',
#  'الباتشولي الترابي الرديء',
#  'راتنج إليمي',
#  'أزهار الوستارية',
#  'بلسم جرجان.',
#  'زهرة الإيلانغ',
#  'بنزيل ميثوكسيديبنزويل ميثان',
#  'بلسم جرجون',
#  'رائحة الأخشاب البيضاء',
#  'أشجار الليمون.',
#  'الجلود الدافئة',
#  'مندرين',
#  'بلسم بيرو',
#  'شقائق النعمان',
#  'العنبر الحلو',
#  'العود بالاو',
#  'الجيرانيوم',
#  'الحلوي',
#  'زهور البرجموت',
#  'سيترال (أصفر 5).',
#  'هيدروكسي بينزويل هيكسيل بنزوات',
#  'البنفسج البودرة',
#  '"البلسم',
#  'اللابدانوم (الروكروز)',
#  'أخشاب جورجيا',
#  'خلاصة نبتة القرّيض الجلد',
#  'إيثيل ميثيل. جرين 3 (Ci 42053)',
#  'الفاكهة الحمراء',
#  'الرم الذهبي',
#  'سيلينول OL.',
#  'راتينج',
#  'جلود جافة',
#  'برتقال الأحمر',
#  'الماغونليا',
#  'دخان',
#  'طحالب السنديان',
#  'الروائح الخضراء',
#  'جراناديلا',
#  'الطبيعية',
#  'ثمر العليق',
#  'أوراق كرمة',
#  'ليمونينول',
#  'إيثيل هكسيل ميثوكسينامات',
#  'لينومين',
#  'أشجار السرو',
#  'خشب الزيتون',
#  'الزهور الاستوائية.',
#  'عشب المتة',
#  'أناناس',
#  'أشجارالتين',
#  'مطلق',
#  'مسك,فل',
#  'المكونات البحرية',
#  'ماراكويا',
#  'الألدهيدات',
#  'CI 14700 ( RED 4)',
#  'رقيب الشمس',
#  'نبات الشيح',
#  'زهور إيجلنتين',
#  'هايتي',
#  'الفاوانيا',
#  'براعم',
#  'الخشب الكشميري',
#  'عبقة,مسك',
#  'سيناميل الكحول',
#  'لبان اللابدانوم',
#  'Grapefruit',
#  'حبوب التونكا',
#  'حبوب التونكا من فنزويلا',
#  'هيدروكسي سيترونولول',
#  'القرفه',
#  'الأخشاب الحمراء',
#  'الجلد;',
#  'زهرة الأوسمانثوس',
#  'شجر الأرز',
#  'السيكلمن',
#  'الأرز الفرجيني',
#  'والفل',
#  'بتيت جرين من أوروجواي,لبان',
#  'اوراق البرتقال',
#  'أكوا / ماء / ماء',
#  'رائحة خشب العنبر',
#  'أوجينول',
#  'أخشاب الهلال.',
#  'كمثرى الناشي',
#  'الجلد المدبوغ',
#  'رحيق الأزهار',
#  'فاكهة الدراجون',
#  'الميموزا',
#  'جوري',
#  'العسل الأسود',
#  'جلود',
#  'مسك التبت',
#  'الماندرين كالابريا',
#  'وردة ـ خشب الصندل',
#  'ورق الغار',
#  'القطنية',
#  'مواد حيوانية',
#  'كوراكو',
#  'أوراق توت العليق',
#  'الغلابانوم',
#  'أخشاب الأرز الحارة',
#  'اللابدون',
#  'ليمون,قهوة',
#  'الكراميل.',
#  'نفحات حسية',
#  'التوت البري',
#  'بتلات الورد',
#  'الفريزيا الصفراء',
#  'برغموت إيطالي',
#  'بتلات الورود',
#  'ليمون,لافندر',
#  'الوردة الزرقاء',
#  'خزامى,        خشب الغاياك الباراغواي',
#  'بلسم الكوبيبا',
#  'زيت البرجموت',
#  'هيل جواتيمالا',
#  'فانيليا جورمند',
#  'زهر الأوسناتثوس',
#  'المبخر',
#  'خشب كشمير',
#  'أكاسيا',
#  ' الخزامى',
#  'White Musk',
#  'زهرة الأيرس',
#  'اللور',
#  'عصير النكتارين',
#  'مياه البحار',
#  'التونك',
#  'ميرامية متصلبة',
#  'زهرة اللاليك',
#  'الإنجليزي',
#  'عبقة صينية,عطفة',
#  'الماندرين الصقيلي',
#  'الهيمالايا ليمون جراس',
#  'نوتات محمصة',
#  'الف',
#  'Pine Tree',
#  'زيت الورد الدمشقي',
#  'البارود',
#  'اللبدانوم',
#  'سيناميل.',
#  'بوتيل ميثوكسيديبنزويلميثان',
#  'نكتار خوخ',
#  'البرالين',
#  'الكمثري المتجمد',
#  'كشمش أسود,بتشول',
#  'ورد,روائح خشبية',
#  'السوس',
#  'خشب الصندل الناعم',
#  'coconut',
#  'هيدروكسيسيترونيلال',
#  'جزيء بوماروزا (نفحات الفاكهة المجففة)',
#  ' الشيح',
#  'حمض الستريك',
#  'لبلاب',
#  'أشجار الأبانوس',
#  'ورد أبيض',
#  'طحلب السنديان - السنديان حزازيات',
#  'التانجرين اليوسفي',
#  'Benzoin',
#  'الأخشاب البيضاء الناعمة',
#  'زهور الليلك',
#  'لليمون',
#  'فاكهة الحب',
#  'الساليسيلات',
#  'مِسك أبيض',
#  'زذاذ البحر',
#  'ورق برتقال مر',
#  'pepper',
#  'أزهار التفاح',
#  'والجلد',
#  'يلنغ يلانغ',
#  'أخشاب لصندل',
#  'زبدة اللوز',
#  'سيترونيلات',
#  'والروم',
#  'فروت',
#  'الكيري',
#  'روائح خشبيىة',
#  'فلفل أوسود',
#  'الكمون',
#  'مريمية,فاوانيا',
#  'روح اللبان العماني',
#  'فاكهة حمراء',
#  'زهرة ليمون',
#  ' خشب  الأرز',
#  'بيرش',
#  'أمونيوم أكريلويد ميثيل تورات / Vp كوبوليمر',
#  'لورينكس',
#  'بالو سانتو',
#  'الليلك الأخضر',
#  'بنزيل كحول',
#  'نفحات',
#  'أزهار المشمش',
#  'التوت الوردي',
#  'أسيتات توكوفيرل',
#  'ياسمين,جلد',
#  'البساتين',
#  'دينات الكحول.',
#  'شجرة السرو',
#  'vanilla',
#  '(استيراكس) العبهر',
#  'الفلفل البيروفي',
#  'زهر الحمضيات',
#  'ياسمين,مسك',
#  'الليمون. ملاحظات الوسطى: الياسمين',
#  'التوت الاحمر',
#  'Ylang Ylang',
#  'خلاصة الباتشولي',
#  'الكباد',
#  'ورد,جلد',
#  'الأخشاب السوداء',
#  'سيدر أطلسي,عنبر',
#  'الماء المنشط',
#  'البودر',
#  'الحليب',
#  'العسل.',
#  'يوسفي أخضر',
#  'فارنيول',
#  'مياه)',
#  'فارنيسو',
#  'CI 60730 (EXT. VIOLET 2).',
#  'العود التايلاندي',
#  'حليب التين',
#  'Black Currant Juice',
#  'Pear',
#  'شينتو',
#  'لافندر,زنبق',
#  'زهور البرتقال.',
#  'بخور,ياسمين',
#  'عنبر توليد',
#  'وجذر السوسن',
#  'Rose Water',
#  'الجوهر المطلق',
#  'إيثيلهيكسيل الساليسيلات',
#  'برغموت',
#  'Petit Grain',
#  'عصير البطيخ',
#  'حلوى المعكرونة',
#  'الياسمين السامباكي',
#  'برغموت,جوزة الطيب',
#  'شجر المر',
#  'زهرة يلانغ يلانغ ,ياسمين',
#  'الأرز الأبيض',
#  'الجلود العطرية',
#  'الحامضي',
#  'الحبهان',
#  'الأيلنغ',
#  'ألورد الدمشقي',
#  'ورد بلغاري,فانيليا',
#  'الأزرق',
#  'الليمون\xa0الإيطالي',
#  'ملكة الليل',
#  'إيجول',
#  'هيدروكسي هيدروسينامات',
#  'الكمشمش الأسود',
#  'الشيكولاتة',
#  'فلفل حار',
#  'بذور مسك مالو',
#  'الورود البيضاء',
#  'الورد الأحمر التركي',
#  'المريمية البيضاء',
#  'الأزهار المسكية',
#  'بيوتيل ميثوكسي ديبينزويل ميثان',
#  'خشب حسي.',
#  'الميموزا البيضاء',
#  'حبهان',
#  'زهر برتقال',
#  'الحكيم',
#  ...]

# %%
for i in all_comp:
    df[i] = False

# %%
for i in df.columns:
    if '.' in i:
        print(i.replace('.', ''))
# Out:
# المارشيمللو
# أعواد الفانيليا
# الكرز
# بذور الجزر
# طحلب أبيض
# أخشاب الآراك
# الخشب
# شجر الويستاريا
# أوراق أمبرين الخشبية
# سيتالوكس
# جادور
# الكمثري
# سيترونيل ساليسيلات
# لينالول - ليمونين - سيترونيلول - جيرانيول - ميثيل 2-أوكتينوات
# الكراوية
# الزعفران
# الكاكاو
# نجيل الهند هياتي
# إيزوجينول
# الفواكه
# تونكا محمص
# إكليل الجبل
# العنبر الرمادي
# البتولا
# الأوكالبتوس
# هيدروكسي إيثيول إيزيولوجين
# النرجس
# الليمون
# الراتنجات الحلوة ياسمين سمباك
# الزعتر
# النفحات الخشبية
# العنبر
# دينات الكحول (كحول Sd 39-C)
# الفاوانيا
# جوزة الطيب
# لينولول
# المكونات الخشبية
# الكاراميل
#  المسك
# زهر البرتقال
# بنتاريثرتييل تترا دي تي بيوتيل
# الماندرين
# الجزر البذور
# نجيل الهند
# الزهور
# خشب الأرز
#  دهن العنبر
# الياسمين الصيني
# بلسم جرجان
# أشجار الليمون
# سيترال (أصفر 5)
# إيثيل ميثيل جرين 3 (Ci 42053)
# سيلينول OL
# الزهور الاستوائية
# أخشاب الهلال
# الكراميل
# سيناميل
# دينات الكحول
# الليمون ملاحظات الوسطى: الياسمين
# العسل
# CI 60730 (EXT VIOLET 2)
# زهور البرتقال
# خشب حسي
# خشب الأرز من فرجينيا
# المرمرية
# الليمونين
# خشب الارز
# الفانيليا التاهيتي
# مسك أبيض
# بنزيل بنزوات
# الكشمش الأسود
# بنزيل الكولين
# الورد السويسري
# الأواكموس- طحلب البلوط
# الكحول
# المر
# التوت
# with intricate gold details
# عسل أبيض
# براعم البرتقال
# الكحول دينات
#  الطحالب
#
#  العنبر
# ورد بنفسج
# زيت خشب الأرز
# التين
# أوراق الباتشولي الإندونيسية
# ألورد
# دهن العود الكمبودي
# أمبروكسان
# بربون الفانيليا
# زهرة القرنبيل
# بهارات
# البرتقال المر
# ورد باي الجاوي
# الأرز
# أخشاب الكشمير
# ألفا إيزوميثيل أيونون؛ كحول البنزيل بنزوات البنزيل؛ كحول القرفة السترال سيترونيلول الكومارين جيرانيول الليمونين لينالول
# ليمونين
# الزهور البيضاء
# والمسك
# الياقوت الأزرق
# سيترال
# الأبيض
# النرجس البري
# الباتشولي
# جلد
# هيدروكسيد
# الجريب فروت
# دهن العود اللاوسي
# خشب العنبر
# ثلاثة أزهار ليلية
# الخوخ
# البخور العربي
# راتينج
# اللوز
# أرز
# روائح النظافة
# بنتاريريتيلي تترا دي تي بيوتيل هيدروكسي هيدروسينامات
# والغلالة
# سيتيل
# قصب السكر
# الشيكولاتة البيضاء
# بنزي كحول
#  خشب الساج
# بنزيل سيناميت
# خشب الابنوس
# بوتيل فينيل ميثيل بروبيونال
# الهيل
# اللوتس
# جيرانيلول
# حبوب التونكا
# غيرانيول
# الرمان
# الفانيلا
# جذور السوسن
# أخشاب الصندل
# والبتشولي
# أشجار الصنوبر
# بلسم التولو
# يوجينول
# جيرانيول
# القندس
# البرالين السائل
# العود النقي
# فانيلا
# البنزوين
# توكوفير بلو
# وزبدة السوسن
# تريس (رباعي ميثيل هيدروكسي)
# كاسيا,يوزو
# شيكولاتة
# ماء زمزم
# الراتنج
# الفانيلا
# كومارين
# حمض السوربيك
# أخشاب العود
# والعنبر
# دهن العود الكلاسيكي
# الطحلب
# مكونات خضراء
# المسك
# زئبق الوادي
# والأرز
# بوتيل ميثوكسي ديبينزويل ميثان من أصل نباتي 80٪ حجم
# سترونيلول
# بنزيل الكحول
# التوت الأحمر
# دينات الكحول (كحول إس دي 39-سي)
# الورد
# خشب الآكيغالاود
# الشوكولاتة البيضاء
# خشب
# مسك الروم
# البارد
# توكوبيرول
# روائح خشبية
# المعتق
# فانيليا مدغشقر
# والفانيليا
# طحلب البلوط
# كاشمران
# إيزويوجينول
# CI 60730 (خارجي البنفسجي 2)
#  أوركيد الفانيلا
# الفانيليا الفرنسية
# أخشاب العنبر
# حلوي اللوز
# كحول سيترال
# أمبريت
# الأمبروكسان
# الكشمير
# الشوكولاتة الداكنة
# سترال
# تونكا
#  الفانيليا
# الكومارين
# العنبر الأبيض
# فريزيا
# د-ليمونين
# المسكتة
# لابدانوم
# بوتيل ميثوكسيديبنزويلميثان
# Cinnamon
# أخشاب الورد من بالي
# كحول
# رائحة الطبينه
# ساليسيلات
# بوربون الفانيليا
# زهر شجرة التفاح زهر العسل
# اللابدانوم
# البودرة
# الجلد المدبوغ الناعم
# زنبق الوادي ملاحظات القاعدة: الخشب
# شجرة الزيتون
# طحلب
# الجلود
# البهارات الهندية
# سيام الجاوي
# زهور القطن
# ستيراكس (العبهر)
# ميثيل 2-أوكتينوات
# زنبق أبيض
# البلوط
# زهور الأرجواني
# المسك من التبت
# الصمغ الراتينجي
# بتلات الورد
# مستخلص خشب الأرز الأبيض
# الفل
# المريمية
# نجيل الهند هايتي
# أصفر 6 (CI 15985)
# النوتات الإيطالية
# الأزهار
# السوسن
# كحول بنزيلي
# Oud
# عنبر
# توكوفيرول
# الورد البلغاري
# البرجموت
# هيكسيل سينامال
# أخشاب الغاياك
# حليب جوز الهند
#  خشب الكستناء
# طحلب الباتشولي
# فانيليا تاهيتي
# خشب السنديان
# بوتيل فينيل ميثيل
# الشاي الأسود
# (فارنيسول)
# أخشاب الفانيليا
# الفانيليا
# العطرية
# الورد ماغنوليا
# الفلفل الوردي
# المانجو
# ايفرينا بروناستري (اوكموس)  اكستراكت
# الداكنة
# ورود بيضاء
# الأخشاب
# زهرة القطن
# الأخشاب الجافة
# أرز أطلس
# بوتيل ميثوكسيديبينزويل ميثان الكحول
# أخشاب الأرز الأطلسي
# تاجيتس
# فارنسول
# بلسم تولو
# الأخشاب البيضاء
# باتشولي
# الغار
# بينتيريتيريتيول-تيتروكسيل
# طحلب السنديان
# النعناع جريب فروت
# القطن
# كمأ
# الراعي
# رائحة الازهار
# الطحالب
# دهن العود
# اللافندر
# الراوند
# بينتيريثريتيل-تيترا هيدروكسي هيدروسينامات
# amber
# جيرانيول سيترونيلول
# الخشب الأصفر
# سي 60730 (إكست بنفسج 2)
# بوتيلين جلايكول / ديكابريتان
# بيهتول 7
# أخشاب الأرز
# الشاي
# برالين
# الليمون الصقيلي
# ألكتريول ج
# فول التونكا
#  ألفا-أيزو ميثيل أيونون
# القرفة
#  الجلد
# شجرة السرو
# الفلفل الأسود
# خشب الساج
# بنزويك حم
# إيثيل هيكسيل ساليسيلات
# والكراميل
# هيكسيل سينسلونيل
# الجلد المدبوغ
# كحول قرفة
# 2-أوكتينوات
# خشب العود
# السكر
# كحول دينات
# مستخلص الأخشاب البيضاء
# نوتات أروماتيك
# الشيكولاتة
# العنبر اللإيطالي
#  جلد الغزال
# فواكه حمراء
# الأرز الأحمر
# ميثيل أنثر / 1)
# الهيلوتروب
# سيوجين الأزرق
# أيزووجينول
# الشيكولاته البيضاء
# بوتيلين جلايكول ديكابريلات / ديكابريلات
# التبغ
# سيترونيلول
#  طحلب البلوط
# إيجينول
# والأمبريت
# الحمضيات
# العود
# الطائفي
# خلاصة الأرز الأبيض
# بنزين
# السترال
# قرفة
# الراتنجات
# دينات الكحول عطر
# ونجيل الهند
# مسك
# الماء
# المسك الأبيض
# أيوجينول
# خشب الغاياك
# حشائش العنبر
# سيترونولول
#  أرز
# الزباد
# بنزوات البنزيل
# بتول
# اللبان
# ورد سبارتا
# البخور
# هيدروكسي كرونيلال
# أوراق التبغ
# كحول بنزيل
# الفانيليا المطلقة
# الجاوي
# الجلد
# خشب الصندل
# زهور البنفسج
# بخور
# العود العنبري
# دينات الكحول (كحول SD 39-C)
# حليب اللوز
# الإيلنغ
# نجيل الهند الهايتي
# عود
# الياسمين
# دينات الكحول عطر؛ مياه أكوا؛ البنزيل الساليسيلات؛ إيثيل هكسيل ميثوكسيسينامات؛ بوتيل ميثوكسيديبنزويل ميثان؛ إيثيل هكسيل ساليسيلات
# آنيو
# التونكا
# لينالول
# بتشولي إندونيسي
# شجرة اللوز
# الطبيعي
# التوابل
# البرغموتالتوت البري
# الباتشولي الصيني
# الهند
# جلد الظباء
# عود الهلال
# الأخشاب الثمينة
# خشب الكشمير
# أصفر 19140 البنفسجي 2
# الجلود الفاخرة
# البنفسج
# الورد الطائفي
# الزعفران
# راتنج الدخان
# أخشاب الأرز من فرجينيا
# زهرة سانتيفوليا
# الصندل
# اخشاب الأرز
# الفلفل
# شوكولا بيضاء
# فانيليا
#  الأخشاب
# الأخشاب الحمراء
# فارنيسول
# الورد التركي
# القرنفل
# الرائحة: دينات الكحول (كحول SD 39-C)
# الاخشاب
# مختلف الروائح الخشبية
# أوراق الكشمش الأسود
# راوند نجيل الهند
# بنزيلو كحول
# البرجموت الصقيلي
